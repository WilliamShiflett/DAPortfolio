# %%
# %%capture
# %load_ext sql
# %sql sqlite:///chinook.db
# Out:
# 'Connected: None@chinook.db'

# %% [markdown]
# This project uses the Chinook database, which contains information about a music shop.
#
# The commands preceded by % are built-in magic commands that allow for things like output to be displayed in Jupyter notebooks.
#
# The command %%sql tells the Jupyter notebook "Get ready for some SQL."
#
# The command "%sql sqlite:///chinook.db" allows us to connect to this database. Let's explore what's inside it using SQL's  "type" attribute.

# %%
# %%sql
# SELECT
#     name,
#     type
# FROM sqlite_master
# WHERE type IN ("table","view");
# Out:
# Done.
# [('album', 'table'),
#  ('artist', 'table'),
#  ('customer', 'table'),
#  ('employee', 'table'),
#  ('genre', 'table'),
#  ('invoice', 'table'),
#  ('invoice_line', 'table'),
#  ('media_type', 'table'),
#  ('playlist', 'table'),
#  ('playlist_track', 'table'),
#  ('track', 'table')]

# %% [markdown]
# The query above shows that the Chinook database contains eleven tables.
#
# Since I'm connected to the Chinook database, Jupyter will assume that any of my FROM statements refer to these tables.
#
# The tables themselves contain columns. We'll take a look at a few of them below- specifically invoice line, track, and genre.

# %%
# %%sql
# SELECT * FROM invoice_line
# LIMIT 5;
# Out:
# Done.
# [(1, 1, 1158, 0.99, 1),
#  (2, 1, 1159, 0.99, 1),
#  (3, 1, 1160, 0.99, 1),
#  (4, 1, 1161, 0.99, 1),
#  (5, 1, 1162, 0.99, 1)]

# %%
# %%sql
# SELECT * FROM track
# LIMIT 5;
# Out:
# Done.
# [(1, 'For Those About To Rock (We Salute You)', 1, 1, 1, 'Angus Young, Malcolm Young, Brian Johnson', 343719, 11170334, 0.99),
#  (2, 'Balls to the Wall', 2, 2, 1, None, 342562, 5510424, 0.99),
#  (3, 'Fast As a Shark', 3, 2, 1, 'F. Baltes, S. Kaufman, U. Dirkscneider & W. Hoffman', 230619, 3990994, 0.99),
#  (4, 'Restless and Wild', 3, 2, 1, 'F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. Dirkscneider & W. Hoffman', 252051, 4331779, 0.99),
#  (5, 'Princess of the Dawn', 3, 2, 1, 'Deaffy & R.A. Smith-Diesel', 375418, 6290521, 0.99)]

# %%
# %%sql
# SELECT * FROM genre;
# Out:
# Done.
# [(1, 'Rock'),
#  (2, 'Jazz'),
#  (3, 'Metal'),
#  (4, 'Alternative & Punk'),
#  (5, 'Rock And Roll'),
#  (6, 'Blues'),
#  (7, 'Latin'),
#  (8, 'Reggae'),
#  (9, 'Pop'),
#  (10, 'Soundtrack'),
#  (11, 'Bossa Nova'),
#  (12, 'Easy Listening'),
#  (13, 'Heavy Metal'),
#  (14, 'R&B/Soul'),
#  (15, 'Electronica/Dance'),
#  (16, 'World'),
#  (17, 'Hip Hop/Rap'),
#  (18, 'Science Fiction'),
#  (19, 'TV Shows'),
#  (20, 'Sci Fi & Fantasy'),
#  (21, 'Drama'),
#  (22, 'Comedy'),
#  (23, 'Alternative'),
#  (24, 'Classical'),
#  (25, 'Opera')]

# %% [markdown]
# Say we want to select three tracks of different genres to add to our store.
#
# One way to determine which tracks would sell best would be to discover which three music genres sell best in the USA. We can do this by checking the number of tracks sold by Genre in the USA as a percentage of all tracks sold in the USA.
#
# First, let's get the denominator of that percentage by finding the number of tracks purchased by customers with addresses in the USA.

# %%
# %%sql
# SELECT c.first_name,
#     c.state,
#     SUM(il.quantity) total_quantity_usa
# FROM customer c
# LEFT JOIN invoice i ON i.customer_id=c.customer_id
# LEFT JOIN invoice_line il ON il.invoice_id=i.invoice_id
# WHERE c.country="USA";
# Out:
# Done.
# [('Julia', 'UT', 1051)]

# %% [markdown]
# We can use this query as a sub-query in our final query.

# %%
# %%sql
# SELECT i.billing_country country,
#     g.name genre_name,
#     SUM(il.quantity) genre_quantity_USA,
#     CAST(SUM(il.quantity) AS FLOAT) / (SELECT SUM(il.quantity) total_quantity_usa
#                                         FROM customer c
#                                         LEFT JOIN invoice i ON i.customer_id=c.customer_id
#                                         LEFT JOIN invoice_line il ON il.invoice_id=i.invoice_id
#                                         WHERE c.country="USA") percentage_tracks_USA
# FROM track t
# INNER JOIN genre g ON g.genre_id=t.genre_id
# INNER JOIN invoice_line il ON il.track_id=t.track_id
# INNER JOIN invoice i ON i.invoice_id=il.invoice_id
# WHERE country="USA"
# GROUP BY country, genre_name
# ORDER BY genre_quantity_USA DESC;
# Out:
# Done.
# [('USA', 'Rock', 561, 0.5337773549000951),
#  ('USA', 'Alternative & Punk', 130, 0.12369172216936251),
#  ('USA', 'Metal', 124, 0.11798287345385347),
#  ('USA', 'R&B/Soul', 53, 0.05042816365366318),
#  ('USA', 'Blues', 36, 0.03425309229305423),
#  ('USA', 'Alternative', 35, 0.03330161750713606),
#  ('USA', 'Latin', 22, 0.02093244529019981),
#  ('USA', 'Pop', 22, 0.02093244529019981),
#  ('USA', 'Hip Hop/Rap', 20, 0.019029495718363463),
#  ('USA', 'Jazz', 14, 0.013320647002854425),
#  ('USA', 'Easy Listening', 13, 0.012369172216936251),
#  ('USA', 'Reggae', 6, 0.005708848715509039),
#  ('USA', 'Electronica/Dance', 5, 0.004757373929590866),
#  ('USA', 'Classical', 4, 0.003805899143672693),
#  ('USA', 'Heavy Metal', 3, 0.0028544243577545195),
#  ('USA', 'Soundtrack', 2, 0.0019029495718363464),
#  ('USA', 'TV Shows', 1, 0.0009514747859181732)]

# %% [markdown]
# In the USA, Punk, Blues, and Pop are ahead of Hip-Hop, which suggests that we should add tracks from these genres to our USA catalogue.
#
# Next, we'll analyze the performance of different sales support agents, specifically the value of purchases associated with some of the top and lowest performers.

# %%
# %%sql
# SELECT DISTINCT e.first_name || " " || e.last_name full_name,
#         e.employee_id,
#         e.title
# FROM employee e
# LEFT JOIN customer c ON c.support_rep_id=e.employee_id;
# Out:
# Done.
# [('Andrew Adams', 1, 'General Manager'),
#  ('Nancy Edwards', 2, 'Sales Manager'),
#  ('Jane Peacock', 3, 'Sales Support Agent'),
#  ('Margaret Park', 4, 'Sales Support Agent'),
#  ('Steve Johnson', 5, 'Sales Support Agent'),
#  ('Michael Mitchell', 6, 'IT Manager'),
#  ('Robert King', 7, 'IT Staff'),
#  ('Laura Callahan', 8, 'IT Staff')]

# %% [markdown]
# Note also that there are only three Sales Support Agents for a comparatively large number of customers.
#
# This strongly suggests that we will need a left join, with employees as the left table.

# %%
# %%sql
# SELECT e.first_name || " " || e.last_name full_name,
#         e.title,
#         date(e.hire_date) hire_date,
#         SUM(i.total) total_sales
# FROM employee e
# LEFT JOIN customer c ON c.support_rep_id=e.employee_id
# INNER JOIN invoice i ON i.customer_id=c.customer_id
# GROUP BY full_name;
# Out:
# Done.
# [('Jane Peacock', 'Sales Support Agent', '2017-04-01', 1731.510000000004),
#  ('Margaret Park', 'Sales Support Agent', '2017-05-03', 1584.0000000000032),
#  ('Steve Johnson', 'Sales Support Agent', '2017-10-17', 1393.9200000000028)]

# %% [markdown]
# Note that Jane Peacock has the most sales, but has also been working at the Chinook record store for the longest out of all of the Sales Support Agents.
#
# For the next task, we need to calculate the total number of customers, total value of sales, average value of sales per customer, and the average order value.
#
# Some countries only have one customer. We'll combine these countries into a category called "Other," but we'll need to find and flag them before we do.

# %%
# %%sql
#
# SELECT
#     CASE
#         WHEN (SELECT COUNT(*)
#              FROM customer
#              WHERE country=c.country)=1 THEN "Other"
#         ELSE c.country
#     END
#     AS new_country,
#         COUNT(*) total_customers
# FROM customer c
# GROUP BY new_country;
# Out:
# Done.
# [('Brazil', 5),
#  ('Canada', 8),
#  ('Czech Republic', 2),
#  ('France', 5),
#  ('Germany', 4),
#  ('India', 2),
#  ('Other', 15),
#  ('Portugal', 2),
#  ('USA', 13),
#  ('United Kingdom', 3)]

# %% [markdown]
# How does the code above work?
#
# The secret is in the CASE statement, which loops through each country in the customer table, counts the data records for each country, and records the result in a column named COUNT(\*).
#
# Specifically, the CASE statement is:
#
# 1.) looping through the subquery's "customer" table's country column and picking a value,
# 2.) checking if that value is in the country column in the FROM clause's "customer" table,
# 3.) selecting only records with that value from the "customer" table, and
# 4.) counting all of the records in that selection and recording the count in a column named COUNT(\*).
#
# Since the CASE state loops through one value at a time, the subquery returns a single value. If that value is "1", the column "new_country" gets the value "Other." If not, it gets the original name of the country.
#
# Now that we know how the subquery works, we can expand it.

# %%
# %%sql
# WITH
# customers_by_country AS
# (
#     SELECT
#         CASE
#             WHEN (SELECT COUNT(*)
#                  FROM customer
#                  WHERE country=c.country)=1 THEN "Other"
#             ELSE c.country
#         END
#         AS new_country,
#         c.customer_id,
#         il.*
#     FROM customer c
#     INNER JOIN invoice i ON i.customer_id=c.customer_id
#     INNER JOIN invoice_line il ON il.invoice_id=i.invoice_id
# )
# SELECT country,
#         total_customers,
#         total_sales_value,
#         average_customer_sales,
#         average_order_value
# FROM
# (
# SELECT
#     new_country country,
#     COUNT(DISTINCT customer_id) total_customers,
#     SUM(unit_price) total_sales_value,
#     SUM(unit_price) / COUNT(DISTINCT customer_id) average_customer_sales,
#     SUM(unit_price) / COUNT(DISTINCT invoice_id) average_order_value,
#     CASE
#         WHEN new_country="Other" THEN 0
#         ELSE 1
#     END
#     AS sort_index
# FROM customers_by_country
# GROUP BY new_country
# ORDER BY sort_index DESC, total_sales_value DESC
#     )
# ;
# Out:
# Done.
# [('USA', 13, 1040.490000000008, 80.03769230769292, 7.942671755725252),
#  ('Canada', 8, 535.5900000000034, 66.94875000000043, 7.047236842105309),
#  ('Brazil', 5, 427.68000000000245, 85.53600000000048, 7.011147540983647),
#  ('France', 5, 389.0700000000021, 77.81400000000042, 7.781400000000042),
#  ('Germany', 4, 334.6200000000016, 83.6550000000004, 8.161463414634186),
#  ('Czech Republic', 2, 273.24000000000103, 136.62000000000052, 9.108000000000034),
#  ('United Kingdom', 3, 245.52000000000078, 81.84000000000026, 8.768571428571457),
#  ('Portugal', 2, 185.13000000000022, 92.56500000000011, 6.3837931034482835),
#  ('India', 2, 183.1500000000002, 91.5750000000001, 8.72142857142858),
#  ('Other', 15, 1094.9400000000085, 72.99600000000056, 7.448571428571486)]

# %% [markdown]
# The last question we need to answer is: what percentage of purchases are individual tracks, and what percentage are whole albums.
#
# This is a little tricky, but the answer is important: the record store might not need to buy entire albums itself if demand for its product is limited to tracks. Note that the cost of an album is the cost of its separate tracks.
#
# The simplest way to do this is to determine if an invoice_id has all tracks from an album. If so, we'll consider that invoice to be an album purchase. If not, we'll consider the purchases to be individual.
#
# First, we'll make a selection that tells us how many tracks were purchased from each album for each invoice.

# %%
# %%sql
# SELECT il.invoice_id,
#     t.album_id,
#     t.track_id,
#     a.title album_title,
#     COUNT(il.quantity) number_of_tracks
# FROM track t
# INNER JOIN invoice_line il ON il.track_id=t.track_id
# INNER JOIN album a ON a.album_id=t.album_id
# GROUP BY il.invoice_id, t.album_id
# LIMIT 400;
# Out:
# Done.
# [(1, 91, 1173, 'Use Your Illusion I', 16),
#  (2, 20, 201, 'The Best Of Buddy Guy - The Millenium Collection', 1),
#  (2, 34, 392, 'Chill: Brazil (Disc 2)', 1),
#  (2, 39, 482, 'International Superhits', 1),
#  (2, 66, 819, 'The Battle Rages On', 1),
#  (2, 73, 1119, 'Unplugged', 1),
#  (2, 134, 1641, 'Led Zeppelin III', 1),
#  (2, 190, 2324, 'The Best Of R.E.M.: The IRS Years', 1),
#  (2, 215, 2651, 'The Police Greatest Hits', 1),
#  (2, 218, 2701, 'Voodoo Lounge', 1),
#  (2, 322, 3476, 'Frank', 1),
#  (3, 203, 2516, 'A-Sides', 1),
#  (3, 214, 2646, 'The Doors', 1),
#  (4, 58, 748, 'Come Taste The Band', 1),
#  (4, 67, 829, "Vault: Def Leppard's Greatest Hits", 1),
#  (4, 146, 1778, 'Seek And Shall Find: More Of The Best (1963-1981)', 1),
#  (4, 153, 1872, 'ReLoad', 1),
#  (4, 203, 2514, 'A-Sides', 1),
#  (4, 207, 2560, 'Mezmerize', 1),
#  (4, 260, 3336, 'Cake: B-Sides and Rarities', 1),
#  (4, 314, 3448, 'English Renaissance', 1),
#  (5, 163, 2002, 'From The Muddy Banks Of The Wishkah [live]', 17),
#  (6, 5, 30, 'Big Ones', 1),
#  (6, 83, 1045, 'My Way: The Best Of Frank Sinatra [Disc 1]', 1),
#  (7, 6, 42, 'Jagged Little Pill', 1),
#  (7, 55, 711, 'Chronicle, Vol. 2', 1),
#  (7, 67, 834, "Vault: Def Leppard's Greatest Hits", 1),
#  (7, 87, 1102, 'Quanta Gente Veio ver--Bônus De Carnaval', 1),
#  (7, 106, 1343, 'Piece Of Mind', 1),
#  (7, 163, 1988, 'From The Muddy Banks Of The Wishkah [live]', 1),
#  (7, 211, 2596, 'The Singles', 1),
#  (7, 214, 2644, 'The Doors', 1),
#  (7, 239, 3024, 'War', 1),
#  (7, 305, 3439, 'Great Recordings of the Century - Mahler: Das Lied von der Erde', 1),
#  (7, 322, 3477, 'Frank', 1),
#  (8, 9, 81, 'Plays Metallica By Four Cellos', 1),
#  (8, 46, 574, 'Supernatural', 1),
#  (8, 118, 1455, 'The Return Of The Space Cowboy', 1),
#  (8, 125, 1560, 'Living After Midnight', 1),
#  (8, 144, 1752, 'Misplaced Childhood', 1),
#  (8, 145, 1758, 'Barulhinho Bom', 1),
#  (8, 183, 2231, 'Dark Side Of The Moon', 1),
#  (8, 185, 2263, 'Greatest Hits I', 1),
#  (8, 203, 2509, 'A-Sides', 1),
#  (8, 233, 2946, "All That You Can't Leave Behind", 1),
#  (9, 20, 196, 'The Best Of Buddy Guy - The Millenium Collection', 1),
#  (9, 21, 206, 'Prenda Minha', 1),
#  (9, 79, 993, 'In Your Honor [Disc 1]', 1),
#  (9, 83, 1041, 'My Way: The Best Of Frank Sinatra [Disc 1]', 1),
#  (9, 101, 1279, 'Killers', 1),
#  (9, 162, 1983, 'Motley Crue Greatest Hits', 1),
#  (9, 173, 2098, 'No More Tears (Remastered)', 1),
#  (9, 271, 3399, 'Revelations', 1),
#  (9, 321, 3456, 'Back to Black', 1),
#  (10, 215, 2663, 'The Police Greatest Hits', 1),
#  (10, 257, 3290, '20th Century Masters - The Millennium Collection: The Best of Scorpions', 1),
#  (11, 49, 610, 'The Essential Miles Davis [Disc 2]', 1),
#  (11, 89, 1138, 'American Idiot', 1),
#  (11, 115, 1419, 'Sex Machine', 1),
#  (11, 181, 2203, 'Ten', 1),
#  (11, 185, 2257, 'Greatest Hits I', 1),
#  (11, 195, 2391, 'Californication', 1),
#  (11, 197, 2420, 'Santana - As Years Go By', 1),
#  (11, 211, 2597, 'The Singles', 1),
#  (11, 214, 2643, 'The Doors', 1),
#  (11, 243, 3072, 'The Best Of Van Halen, Vol. I', 1),
#  (11, 318, 3452, 'SCRIABIN: Vers la flamme', 1),
#  (12, 10, 92, 'Audioslave', 1),
#  (12, 54, 690, 'Chronicle, Vol. 1', 1),
#  (12, 118, 1463, 'The Return Of The Space Cowboy', 1),
#  (12, 215, 2663, 'The Police Greatest Hits', 1),
#  (13, 206, 2553, 'Core', 1),
#  (14, 42, 541, 'Minha História', 1),
#  (15, 65, 807, 'Stormbringer', 1),
#  (15, 120, 1489, 'Are You Experienced?', 1),
#  (15, 241, 3050, 'UB40 The Best Of - Volume Two [uk]', 1),
#  (15, 260, 3336, 'Cake: B-Sides and Rarities', 1),
#  (16, 4, 21, 'Let There Be Rock', 2),
#  (16, 5, 24, 'Big Ones', 1),
#  (16, 9, 83, 'Plays Metallica By Four Cellos', 1),
#  (16, 10, 93, 'Audioslave', 1),
#  (16, 70, 875, 'Djavan Ao Vivo - Vol. 1', 1),
#  (16, 145, 1756, 'Barulhinho Bom', 1),
#  (16, 178, 2160, 'Live On Two Legs [live]', 1),
#  (16, 321, 3460, 'Back to Black', 1),
#  (17, 7, 55, 'Facelift', 2),
#  (17, 115, 1419, 'Sex Machine', 1),
#  (17, 131, 1610, 'IV', 1),
#  (17, 162, 1973, 'Motley Crue Greatest Hits', 1),
#  (17, 179, 2171, 'Pearl Jam', 1),
#  (17, 185, 2270, 'Greatest Hits I', 1),
#  (17, 195, 2400, 'Californication', 1),
#  (17, 203, 2522, 'A-Sides', 1),
#  (17, 206, 2553, 'Core', 1),
#  (17, 207, 2564, 'Mezmerize', 1),
#  (18, 82, 1027, 'The Colour And The Shape', 1),
#  (18, 127, 1583, 'BBC Sessions [Disc 2] [live]', 1),
#  (18, 141, 3142, 'Greatest Hits', 1),
#  (18, 144, 1752, 'Misplaced Childhood', 1),
#  (18, 221, 2736, 'My Generation - The Very Best Of The Who', 1),
#  (19, 11, 105, 'Out Of Exile', 1),
#  (19, 103, 1310, 'Live At Donington 1992 (Disc 1)', 1),
#  (19, 146, 1784, 'Seek And Shall Find: More Of The Best (1963-1981)', 1),
#  (19, 203, 2510, 'A-Sides', 1),
#  (19, 214, 2640, 'The Doors', 1),
#  (19, 216, 2669, 'Hot Rocks, 1964-1971 (Disc 1)', 1),
#  (19, 321, 3460, 'Back to Black', 1),
#  (20, 7, 60, 'Facelift', 1),
#  (20, 11, 102, 'Out Of Exile', 1),
#  (20, 30, 337, 'BBC Sessions [Disc 1] [live]', 1),
#  (20, 72, 905, 'The Cream Of Clapton', 1),
#  (20, 88, 1132, 'Faceless', 1),
#  (20, 252, 3225, 'Un-Led-Ed', 1),
#  (20, 257, 3297, '20th Century Masters - The Millennium Collection: The Best of Scorpions', 2),
#  (20, 260, 3336, 'Cake: B-Sides and Rarities', 1),
#  (20, 267, 3357, 'Worlds', 1),
#  (21, 1, 13, 'For Those About To Rock We Salute You', 1),
#  (21, 116, 1434, 'Emergency On Planet Earth', 1),
#  (21, 118, 1461, 'The Return Of The Space Cowboy', 1),
#  (21, 119, 1473, 'Get Born', 1),
#  (21, 121, 1502, 'Surfing with the Alien (Remastered)', 1),
#  (21, 141, 3135, 'Greatest Hits', 1),
#  (21, 207, 2561, 'Mezmerize', 2),
#  (21, 235, 2971, 'How To Dismantle An Atomic Bomb', 1),
#  (22, 33, 383, 'Chill: Brazil (Disc 1)', 1),
#  (22, 80, 1000, 'In Your Honor [Disc 2]', 1),
#  (23, 1, 14, 'For Those About To Rock We Salute You', 10),
#  (24, 90, 1157, 'Appetite for Destruction', 12),
#  (25, 5, 32, 'Big Ones', 1),
#  (25, 6, 46, 'Jagged Little Pill', 1),
#  (25, 75, 948, 'Angel Dust', 1),
#  (25, 91, 1167, 'Use Your Illusion I', 1),
#  (25, 119, 1477, 'Get Born', 1),
#  (25, 147, 1800, 'The Best Of Men At Work', 1),
#  (25, 180, 2185, 'Riot Act', 1),
#  (25, 241, 3049, 'UB40 The Best Of - Volume Two [uk]', 1),
#  (26, 10, 85, 'Audioslave', 1),
#  (26, 216, 2670, 'Hot Rocks, 1964-1971 (Disc 1)', 1),
#  (27, 101, 1280, 'Killers', 1),
#  (27, 117, 1445, 'Synkronized', 1),
#  (27, 121, 1496, 'Surfing with the Alien (Remastered)', 1),
#  (27, 183, 2230, 'Dark Side Of The Moon', 2),
#  (27, 238, 3014, 'The Best Of 1980-1990', 1),
#  (27, 246, 3105, 'Contraband', 1),
#  (27, 305, 3439, 'Great Recordings of the Century - Mahler: Das Lied von der Erde', 1),
#  (28, 5, 36, 'Big Ones', 1),
#  (28, 74, 932, 'Album Of The Year', 1),
#  (28, 321, 3456, 'Back to Black', 1),
#  (29, 39, 479, 'International Superhits', 1),
#  (29, 82, 1025, 'The Colour And The Shape', 1),
#  (29, 132, 1626, 'Led Zeppelin I', 1),
#  (29, 195, 2395, 'Californication', 1),
#  (29, 200, 2462, 'O Samba Poconé', 1),
#  (29, 261, 3341, 'LOST, Season 4', 1),
#  (30, 5, 33, 'Big Ones', 1),
#  (30, 73, 919, 'Unplugged', 1),
#  (30, 79, 990, 'In Your Honor [Disc 1]', 1),
#  (30, 89, 1139, 'American Idiot', 1),
#  (30, 164, 2013, 'Nevermind', 1),
#  (30, 191, 2341, 'Cesta Básica', 1),
#  (30, 195, 2396, 'Californication', 1),
#  (30, 196, 2413, 'Retrospective I (1974-1980)', 1),
#  (30, 246, 3109, 'Contraband', 1),
#  (30, 321, 3464, 'Back to Black', 2),
#  (31, 221, 2750, 'My Generation - The Very Best Of The Who', 20),
#  (32, 6, 50, 'Jagged Little Pill', 13),
#  (33, 206, 2542, 'Core', 1),
#  (33, 218, 2697, 'Voodoo Lounge', 1),
#  (33, 221, 2736, 'My Generation - The Very Best Of The Who', 1),
#  (33, 258, 3307, 'House of Pain', 1),
#  (34, 49, 610, 'The Essential Miles Davis [Disc 2]', 1),
#  (35, 1, 6, 'For Those About To Rock We Salute You', 1),
#  (35, 9, 80, 'Plays Metallica By Four Cellos', 1),
#  (35, 67, 836, "Vault: Def Leppard's Greatest Hits", 1),
#  (35, 194, 2377, 'By The Way', 1),
#  (35, 322, 3475, 'Frank', 1),
#  (36, 16, 153, 'Black Sabbath', 1),
#  (36, 77, 968, 'The Real Thing', 1),
#  (36, 91, 1168, 'Use Your Illusion I', 1),
#  (36, 120, 1493, 'Are You Experienced?', 1),
#  (36, 127, 1582, 'BBC Sessions [Disc 2] [live]', 1),
#  (36, 183, 2233, 'Dark Side Of The Moon', 1),
#  (36, 215, 2656, 'The Police Greatest Hits', 1),
#  (37, 55, 698, 'Chronicle, Vol. 2', 1),
#  (37, 81, 1014, 'One By One', 1),
#  (37, 91, 1166, 'Use Your Illusion I', 1),
#  (37, 115, 1428, 'Sex Machine', 1),
#  (37, 145, 1763, 'Barulhinho Bom', 1),
#  (37, 257, 3297, '20th Century Masters - The Millennium Collection: The Best of Scorpions', 1),
#  (37, 259, 3329, 'Radio Brasil (O Som da Jovem Vanguarda) - Seleccao de Henrique Amaro', 1),
#  (37, 260, 3336, 'Cake: B-Sides and Rarities', 1),
#  (37, 271, 3392, 'Revelations', 1),
#  (37, 321, 3458, 'Back to Black', 1),
#  (38, 16, 154, 'Black Sabbath', 1),
#  (38, 119, 1472, 'Get Born', 1),
#  (38, 126, 1566, 'Unplugged [live]', 1),
#  (38, 207, 2557, 'Mezmerize', 1),
#  (38, 234, 2960, 'B-Sides 1980-1990', 1),
#  (38, 255, 3272, 'Instant Karma: The Amnesty International Campaign to Save Darfur', 1),
#  (38, 278, 3409, 'Bach: The Cello Suites', 1),
#  (39, 19, 184, 'Chemical Wedding', 1),
#  (39, 138, 1669, 'The Song Remains The Same (Disc 2)', 1),
#  (39, 141, 3142, 'Greatest Hits', 1),
#  (39, 189, 2308, 'New Adventures In Hi-Fi', 1),
#  (39, 196, 2415, 'Retrospective I (1974-1980)', 1),
#  (39, 203, 2519, 'A-Sides', 1),
#  (39, 269, 3366, 'Temple of the Dog', 1),
#  (39, 293, 3424, "Pavarotti's Opera Made Easy", 1),
#  (40, 11, 108, 'Out Of Exile', 1),
#  (40, 44, 553, 'Physical Graffiti [Disc 1]', 1),
#  (40, 54, 686, 'Chronicle, Vol. 1', 1),
#  (40, 132, 1626, 'Led Zeppelin I', 1),
#  (40, 183, 2237, 'Dark Side Of The Moon', 1),
#  (40, 194, 2382, 'By The Way', 1),
#  (40, 207, 2556, 'Mezmerize', 1),
#  (40, 215, 2654, 'The Police Greatest Hits', 1),
#  (40, 221, 2737, 'My Generation - The Very Best Of The Who', 1),
#  (40, 321, 3460, 'Back to Black', 1),
#  (41, 16, 153, 'Black Sabbath', 1),
#  (41, 61, 773, "Knocking at Your Back Door: The Best Of Deep Purple in the 80's", 1),
#  (41, 160, 1947, 'Ace Of Spades', 1),
#  (41, 203, 2511, 'A-Sides', 1),
#  (41, 218, 2698, 'Voodoo Lounge', 1),
#  (41, 233, 2945, "All That You Can't Leave Behind", 1),
#  (41, 260, 3336, 'Cake: B-Sides and Rarities', 1),
#  (41, 321, 3457, 'Back to Black', 1),
#  (42, 1, 13, 'For Those About To Rock We Salute You', 1),
#  (42, 16, 153, 'Black Sabbath', 1),
#  (42, 46, 580, 'Supernatural', 1),
#  (42, 55, 699, 'Chronicle, Vol. 2', 2),
#  (42, 72, 897, 'The Cream Of Clapton', 1),
#  (42, 83, 1047, 'My Way: The Best Of Frank Sinatra [Disc 1]', 1),
#  (42, 214, 2646, 'The Doors', 1),
#  (42, 243, 3074, 'The Best Of Van Halen, Vol. I', 1),
#  (43, 73, 918, 'Unplugged', 1),
#  (43, 91, 1162, 'Use Your Illusion I', 1),
#  (43, 135, 1654, 'Physical Graffiti [Disc 2]', 1),
#  (43, 145, 1768, 'Barulhinho Bom', 1),
#  (43, 163, 1997, 'From The Muddy Banks Of The Wishkah [live]', 1),
#  (43, 191, 2342, 'Cesta Básica', 1),
#  (43, 214, 2641, 'The Doors', 1),
#  (44, 242, 3063, 'Diver Down', 12),
#  (45, 11, 102, 'Out Of Exile', 1),
#  (45, 17, 158, 'Black Sabbath Vol. 4 (Remaster)', 1),
#  (45, 146, 1787, 'Seek And Shall Find: More Of The Best (1963-1981)', 1),
#  (45, 150, 1837, "Kill 'Em All", 1),
#  (45, 155, 1890, 'St. Anger', 1),
#  (45, 162, 1976, 'Motley Crue Greatest Hits', 1),
#  (45, 214, 2649, 'The Doors', 1),
#  (45, 221, 2731, 'My Generation - The Very Best Of The Who', 1),
#  (46, 214, 2649, 'The Doors', 11),
#  (47, 1, 8, 'For Those About To Rock We Salute You', 1),
#  (47, 37, 449, 'Greatest Kiss', 1),
#  (47, 39, 478, 'International Superhits', 1),
#  (47, 171, 2095, 'Blizzard of Ozz', 1),
#  (47, 203, 2518, 'A-Sides', 1),
#  (47, 271, 3396, 'Revelations', 1),
#  (48, 7, 58, 'Facelift', 1),
#  (48, 36, 427, 'Greatest Hits II', 1),
#  (48, 91, 1167, 'Use Your Illusion I', 1),
#  (48, 182, 2210, 'Vs.', 1),
#  (49, 15, 146, 'Alcohol Fueled Brewtality Live! [Disc 2]', 2),
#  (49, 91, 1162, 'Use Your Illusion I', 1),
#  (49, 154, 1877, 'Ride The Lightning', 1),
#  (49, 207, 2561, 'Mezmerize', 1),
#  (50, 122, 1511, 'Jorge Ben Jor 25 Anos', 1),
#  (50, 147, 1794, 'The Best Of Men At Work', 1),
#  (50, 157, 1905, 'Miles Ahead', 1),
#  (50, 178, 2155, 'Live On Two Legs [live]', 1),
#  (50, 199, 2455, 'Maquinarama', 1),
#  (50, 270, 3388, 'Carry On', 1),
#  (50, 321, 3455, 'Back to Black', 1),
#  (51, 5, 34, 'Big Ones', 1),
#  (51, 13, 126, 'The Best Of Billy Cobham', 1),
#  (51, 39, 475, 'International Superhits', 1),
#  (51, 54, 692, 'Chronicle, Vol. 1', 1),
#  (51, 92, 1184, 'Use Your Illusion II', 1),
#  (51, 179, 2171, 'Pearl Jam', 1),
#  (51, 185, 2265, 'Greatest Hits I', 1),
#  (51, 241, 3046, 'UB40 The Best Of - Volume Two [uk]', 1),
#  (52, 216, 2675, 'Hot Rocks, 1964-1971 (Disc 1)', 12),
#  (53, 21, 207, 'Prenda Minha', 1),
#  (53, 125, 1551, 'Living After Midnight', 1),
#  (53, 151, 1846, 'Load', 1),
#  (54, 146, 1790, 'Seek And Shall Find: More Of The Best (1963-1981)', 18),
#  (55, 16, 155, 'Black Sabbath', 1),
#  (55, 30, 349, 'BBC Sessions [Disc 1] [live]', 1),
#  (55, 39, 481, 'International Superhits', 1),
#  (55, 43, 548, 'MK III The Final Concerts [Disc 1]', 1),
#  (55, 125, 1552, 'Living After Midnight', 1),
#  (55, 164, 2006, 'Nevermind', 1),
#  (55, 199, 2453, 'Maquinarama', 1),
#  (55, 206, 2552, 'Core', 1),
#  (55, 216, 2675, 'Hot Rocks, 1964-1971 (Disc 1)', 2),
#  (56, 185, 2270, 'Greatest Hits I', 17),
#  (57, 233, 2948, "All That You Can't Leave Behind", 1),
#  (58, 82, 1029, 'The Colour And The Shape', 1),
#  (58, 144, 1745, 'Misplaced Childhood', 1),
#  (58, 195, 2395, 'Californication', 1),
#  (58, 213, 2630, 'Pure Cult: The Best Of The Cult (For Rockers, Ravers, Lovers & Sinners) [uk]', 1),
#  (58, 214, 2644, 'The Doors', 1),
#  (58, 216, 2669, 'Hot Rocks, 1964-1971 (Disc 1)', 1),
#  (59, 20, 198, 'The Best Of Buddy Guy - The Millenium Collection', 1),
#  (59, 37, 449, 'Greatest Kiss', 1),
#  (59, 83, 1053, 'My Way: The Best Of Frank Sinatra [Disc 1]', 1),
#  (59, 88, 1123, 'Faceless', 1),
#  (59, 118, 1463, 'The Return Of The Space Cowboy', 1),
#  (59, 207, 2563, 'Mezmerize', 1),
#  (59, 214, 2640, 'The Doors', 1),
#  (59, 221, 2731, 'My Generation - The Very Best Of The Who', 1),
#  (59, 260, 3336, 'Cake: B-Sides and Rarities', 1),
#  (59, 271, 3390, 'Revelations', 1),
#  (59, 336, 3491, 'Prokofiev: Symphony No.5 & Stravinksy: Le Sacre Du Printemps', 1),
#  (60, 6, 46, 'Jagged Little Pill', 1),
#  (60, 39, 479, 'International Superhits', 1),
#  (60, 43, 544, 'MK III The Final Concerts [Disc 1]', 1),
#  (60, 82, 1030, 'The Colour And The Shape', 1),
#  (60, 91, 1167, 'Use Your Illusion I', 1),
#  (60, 149, 1826, 'Garage Inc. (Disc 2)', 1),
#  (60, 154, 1875, 'Ride The Lightning', 1),
#  (60, 196, 2416, 'Retrospective I (1974-1980)', 1),
#  (61, 212, 2620, 'Beyond Good And Evil', 12),
#  (62, 10, 97, 'Audioslave', 1),
#  (62, 217, 2680, 'No Security', 1),
#  (62, 237, 2989, 'Rattle And Hum', 1),
#  (63, 1, 8, 'For Those About To Rock We Salute You', 2),
#  (63, 37, 444, 'Greatest Kiss', 1),
#  (63, 163, 1994, 'From The Muddy Banks Of The Wishkah [live]', 1),
#  (63, 270, 3376, 'Carry On', 1),
#  (63, 322, 3470, 'Frank', 1),
#  (64, 6, 50, 'Jagged Little Pill', 13),
#  (65, 42, 539, 'Minha História', 1),
#  (65, 89, 1139, 'American Idiot', 1),
#  (66, 37, 442, 'Greatest Kiss', 1),
#  (66, 116, 1435, 'Emergency On Planet Earth', 1),
#  (66, 145, 1761, 'Barulhinho Bom', 1),
#  (66, 146, 1785, 'Seek And Shall Find: More Of The Best (1963-1981)', 1),
#  (66, 160, 1951, 'Ace Of Spades', 1),
#  (66, 191, 2334, 'Cesta Básica', 1),
#  (66, 270, 3377, 'Carry On', 1),
#  (67, 1, 9, 'For Those About To Rock We Salute You', 1),
#  (67, 9, 84, 'Plays Metallica By Four Cellos', 1),
#  (67, 63, 787, 'Purpendicular', 1),
#  (67, 69, 861, 'Djavan Ao Vivo - Vol. 02', 1),
#  (67, 178, 2164, 'Live On Two Legs [live]', 1),
#  (67, 188, 2287, 'Green', 1),
#  (67, 195, 2401, 'Californication', 1),
#  (67, 196, 2413, 'Retrospective I (1974-1980)', 1),
#  (67, 245, 3099, 'Van Halen III', 1),
#  (67, 322, 3468, 'Frank', 1),
#  (67, 323, 3478, 'Carried to Dust (Bonus Track Version)', 1),
#  (68, 7, 61, 'Facelift', 1),
#  (68, 58, 751, 'Come Taste The Band', 1),
#  (68, 73, 910, 'Unplugged', 1),
#  (68, 138, 1669, 'The Song Remains The Same (Disc 2)', 1),
#  (68, 157, 1903, 'Miles Ahead', 1),
#  (68, 163, 1990, 'From The Muddy Banks Of The Wishkah [live]', 1),
#  (68, 164, 2008, 'Nevermind', 1),
#  (68, 183, 2236, 'Dark Side Of The Moon', 1),
#  (68, 185, 2265, 'Greatest Hits I', 1),
#  (68, 209, 2575, 'Live [Disc 1]', 1),
#  (68, 265, 3353, 'Every Kind of Light', 1),
#  (69, 10, 98, 'Audioslave', 14),
#  (70, 189, 2307, 'New Adventures In Hi-Fi', 1),
#  (71, 185, 2270, 'Greatest Hits I', 17),
#  (72, 5, 30, 'Big Ones', 1),
#  (72, 136, 1658, 'Presence', 1),
#  (72, 207, 2564, 'Mezmerize', 1),
#  (73, 195, 2405, 'Californication', 15),
#  (74, 142, 1743, 'Lulu Santos - RCA 100 Anos De Música - Álbum 01', 1),
#  (74, 244, 3081, 'Van Halen', 1),
#  (75, 4, 22, 'Let There Be Rock', 1),
#  (75, 96, 1233, 'A Real Live One', 1),
#  (75, 120, 1488, 'Are You Experienced?', 1),
#  (75, 162, 1977, 'Motley Crue Greatest Hits', 1),
#  (76, 82, 1032, 'The Colour And The Shape', 13),
#  (77, 4, 22, 'Let There Be Rock', 6),
#  (78, 5, 33, 'Big Ones', 1),
#  (78, 83, 1052, 'My Way: The Best Of Frank Sinatra [Disc 1]', 1),
#  (78, 88, 1126, 'Faceless', 1),
#  (78, 95, 1215, 'A Real Dead One', 1),
#  (78, 206, 2553, 'Core', 1),
#  (78, 211, 2592, 'The Singles', 1),
#  (78, 238, 3006, 'The Best Of 1980-1990', 1),
#  (78, 260, 3336, 'Cake: B-Sides and Rarities', 1),
#  (78, 269, 3370, 'Temple of the Dog', 1),
#  (79, 157, 1915, 'Miles Ahead', 14),
#  (80, 271, 3400, 'Revelations', 1),
#  (81, 43, 545, 'MK III The Final Concerts [Disc 1]', 1),
#  (81, 67, 839, "Vault: Def Leppard's Greatest Hits", 1),
#  (81, 72, 904, 'The Cream Of Clapton', 1),
#  (81, 103, 1314, 'Live At Donington 1992 (Disc 1)', 1),
#  (81, 207, 2554, 'Mezmerize', 1),
#  (81, 243, 3079, 'The Best Of Van Halen, Vol. I', 1),
#  (82, 7, 54, 'Facelift', 1),
#  (82, 105, 1332, 'No Prayer For The Dying', 1),
#  (82, 107, 1348, 'Powerslave', 1),
#  (82, 175, 2120, 'Walking Into Clarksdale', 1),
#  (82, 196, 2417, 'Retrospective I (1974-1980)', 1),
#  (82, 218, 2704, 'Voodoo Lounge', 1)]

# %% [markdown]
# Note that there are some invoices where people buy a number of single tracks from multiple albums, and others where people buy multiple tracks from a single album.
#
# Next, we'll get an idea of how many tracks there are in each album.

# %%
# %%sql
# SELECT a.album_id,
#     a.title,
#     count(t.track_id) number_of_tracks
# FROM album a
# LEFT JOIN track t ON t.album_id=a.album_id
# WHERE a.album_id=91
# GROUP BY a.album_id
# ORDER BY a.album_id
# ;
# Out:
# Done.
# [(91, 'Use Your Illusion I', 16)]

# %% [markdown]
# We're primarily interested in two columns from the two selections: album ID, and count of tracks.
#
# But we also need to consider the the invoice ID, because we need to
#
# 1. loop through the invoice ID (so they should be ordered), </br>
# 2. create a selection for each invoice, </br>
# 3. compare the number of tracks purchased in an invoice with the tracks available for an album, </bt>
# 4. create a new case column that indicates if an invoice's purchases per album constituted purchasing the entire album; we assume this is the case if invoice x purchased y tracks from album z when album z has exactly y tracks.

# %%
# %%sql
# WITH
# invoice_tracks AS
# (
#     SELECT il.invoice_id,
#         t.album_id,
#         COUNT(il.quantity) number_of_tracks_invoice
#     FROM track t
#     INNER JOIN invoice_line il ON il.track_id=t.track_id
#     INNER JOIN album a ON a.album_id=t.album_id
#     GROUP BY il.invoice_id, t.album_id
#     ORDER By il.invoice_id, a.album_id
# ),
# album_tracks AS
# (
#     SELECT a.album_id,
#         count(t.track_id) number_of_tracks_album
#     FROM album a
#     LEFT JOIN track t ON t.album_id=a.album_id
#     GROUP BY a.album_id
#     ORDER BY a.album_id
# ),
# combined_tracks AS
# (
# select it.invoice_id,
#         at.album_id,
#         at.number_of_tracks_album,
#         it.number_of_tracks_invoice,
#         CASE
#             WHEN at.number_of_tracks_album=it.number_of_tracks_invoice
#             AND at.number_of_tracks_album >= 2 THEN "yes"
#             ELSE "no"
#             END
#         AS entire_album_purchase
# from album_tracks at
# LEFT JOIN invoice_tracks it ON it.album_id=at.album_id
# )
#
# SELECT  CAST ((
#         SELECT COUNT(*)
#         FROM combined_tracks
#         WHERE entire_album_purchase="yes"
#         ) AS float) / CAST(COUNT(DISTINCT invoice_id) AS float) percentage_entire_album
# FROM combined_tracks
# ;
# Out:
# Done.
# [(0.18078175895765472,)]

# %%
# %%sql
# WITH
#     invoice_track_reference AS
#         (
#             SELECT il.invoice_id,
#                    MIN(il.track_id) ref_track_id
#             FROM invoice_line il
#             GROUP BY invoice_id
#         )
#
# SELECT *
# FROM invoice_track_reference itr
# LIMIT 50
# ;
# Out:
# Done.
# [(1, 1158),
#  (2, 201),
#  (3, 2516),
#  (4, 748),
#  (5, 1986),
#  (6, 30),
#  (7, 42),
#  (8, 81),
#  (9, 196),
#  (10, 2663),
#  (11, 610),
#  (12, 92),
#  (13, 2553),
#  (14, 541),
#  (15, 807),
#  (16, 16),
#  (17, 55),
#  (18, 1027),
#  (19, 105),
#  (20, 60),
#  (21, 13),
#  (22, 383),
#  (23, 1),
#  (24, 1146),
#  (25, 32),
#  (26, 85),
#  (27, 1280),
#  (28, 36),
#  (29, 479),
#  (30, 33),
#  (31, 2731),
#  (32, 38),
#  (33, 2542),
#  (34, 610),
#  (35, 6),
#  (36, 153),
#  (37, 698),
#  (38, 154),
#  (39, 184),
#  (40, 108),
#  (41, 153),
#  (42, 13),
#  (43, 918),
#  (44, 3052),
#  (45, 102),
#  (46, 2639),
#  (47, 8),
#  (48, 58),
#  (49, 146),
#  (50, 1511)]

# %%
# %%sql
# WITH
#     invoice_track_reference AS
#         (
#             SELECT invoice_id,
#                    MIN(track_id) ref_track_id
#             FROM invoice_line
#             GROUP BY invoice_id
#         )
#
# SELECT purchased_album,
#     COUNT(invoice_id) number_invoices,
#     CAST(COUNT(invoice_id) AS FLOAT)/CAST((SELECT COUNT(*)
#                                           FROM INVOICE) AS FLOAT) percentage
# FROM
#     (
#     SELECT itr.*,
#         CASE
#             WHEN
#                 (
#                    SELECT t.track_id FROM track t
#                    WHERE album_id = (SELECT album_id FROM track t2
#                                      WHERE t2.track_id=itr.ref_track_id)
#
#                    EXCEPT
#
#                    SELECT track_id from invoice_line
#                    WHERE invoice_id=itr.invoice_id
#                 ) IS NULL
#             AND
#                 (
#                    SELECT track_id from invoice_line
#                    WHERE invoice_id=itr.invoice_id
#
#                    EXCEPT
#
#                    SELECT t.track_id FROM track t
#                    WHERE album_id = (SELECT album_id FROM track t2
#                                  WHERE t2.track_id=itr.ref_track_id)
#                 ) IS NULL
#             THEN "Yes"
#             ELSE "No"
#         END AS purchased_album
#     FROM invoice_track_reference itr
#     )
# GROUP BY purchased_album
# ;
# Out:
# Done.
# [('No', 500, 0.8143322475570033), ('Yes', 114, 0.18566775244299674)]

# %%
Next steps:
    Find Album using CASE Statement to match track_id from itr with track id in album
    For that album Except and Inverse-Except statement for invoice tracks and album tracks 
    If both are null, then Album purchase
# Out:
#   File "<ipython-input-17-1748af53fe6b>", line 2
#     Next steps:
#              ^
# SyntaxError: invalid syntax

# %%
# %%sql
# SELECT *
# FROM invoice;
# Out:
# Done.
# [(1, 18, '2017-01-03 00:00:00', '627 Broadway', 'New York', 'NY', 'USA', '10012-2612', 15.84),
#  (2, 30, '2017-01-03 00:00:00', '230 Elgin Street', 'Ottawa', 'ON', 'Canada', 'K2P 1L7', 9.9),
#  (3, 40, '2017-01-05 00:00:00', '8, Rue Hanovre', 'Paris', 'None', 'France', '75002', 1.98),
#  (4, 18, '2017-01-06 00:00:00', '627 Broadway', 'New York', 'NY', 'USA', '10012-2612', 7.92),
#  (5, 27, '2017-01-07 00:00:00', '1033 N Park Ave', 'Tucson', 'AZ', 'USA', '85719', 16.83),
#  (6, 31, '2017-01-10 00:00:00', '194A Chain Lake Drive', 'Halifax', 'NS', 'Canada', 'B3S 1C5', 1.98),
#  (7, 49, '2017-01-12 00:00:00', 'Ordynacka 10', 'Warsaw', 'None', 'Poland', '00-358', 10.89),
#  (8, 59, '2017-01-13 00:00:00', '3,Raj Bhavan Road', 'Bangalore', 'None', 'India', '560001', 9.9),
#  (9, 18, '2017-01-18 00:00:00', '627 Broadway', 'New York', 'NY', 'USA', '10012-2612', 8.91),
#  (10, 31, '2017-01-18 00:00:00', '194A Chain Lake Drive', 'Halifax', 'NS', 'Canada', 'B3S 1C5', 1.98),
#  (11, 38, '2017-01-20 00:00:00', 'Barbarossastraße 19', 'Berlin', 'None', 'Germany', '10779', 10.89),
#  (12, 42, '2017-01-21 00:00:00', '9, Place Louis Barthou', 'Bordeaux', 'None', 'France', '33000', 3.96),
#  (13, 35, '2017-01-22 00:00:00', 'Rua dos Campeões Europeus de Viena, 4350', 'Porto', 'None', 'Portugal', 'None', 0.99),
#  (14, 25, '2017-01-23 00:00:00', '319 N. Frances Street', 'Madison', 'WI', 'USA', '53703', 0.99),
#  (15, 44, '2017-01-25 00:00:00', 'Porthaninkatu 9', 'Helsinki', 'None', 'Finland', '00530', 3.96),
#  (16, 1, '2017-01-26 00:00:00', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', 8.91),
#  (17, 20, '2017-01-28 00:00:00', '541 Del Medio Avenue', 'Mountain View', 'CA', 'USA', '94040-111', 10.89),
#  (18, 24, '2017-02-02 00:00:00', '162 E Superior Street', 'Chicago', 'IL', 'USA', '60611', 4.95),
#  (19, 10, '2017-02-06 00:00:00', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', 6.93),
#  (20, 43, '2017-02-06 00:00:00', '68, Rue Jouvence', 'Dijon', 'None', 'France', '21000', 9.9),
#  (21, 9, '2017-02-07 00:00:00', 'Sønder Boulevard 51', 'Copenhagen', 'None', 'Denmark', '1720', 8.91),
#  (22, 35, '2017-02-08 00:00:00', 'Rua dos Campeões Europeus de Viena, 4350', 'Porto', 'None', 'Portugal', 'None', 1.98),
#  (23, 53, '2017-02-09 00:00:00', '113 Lupus St', 'London', 'None', 'United Kingdom', 'SW1V 3EN', 9.9),
#  (24, 4, '2017-02-10 00:00:00', 'Ullevålsveien 14', 'Oslo', 'None', 'Norway', '0171', 11.879999999999999),
#  (25, 39, '2017-02-11 00:00:00', '4, Rue Milton', 'Paris', 'None', 'France', '75009', 7.92),
#  (26, 55, '2017-02-15 00:00:00', '421 Bourke Street', 'Sidney', 'NSW', 'Australia', '2010', 1.98),
#  (27, 35, '2017-02-15 00:00:00', 'Rua dos Campeões Europeus de Viena, 4350', 'Porto', 'None', 'Portugal', 'None', 7.92),
#  (28, 12, '2017-02-17 00:00:00', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', 2.9699999999999998),
#  (29, 45, '2017-02-17 00:00:00', 'Erzsébet krt. 58.', 'Budapest', 'None', 'Hungary', 'H-1073', 5.9399999999999995),
#  (30, 46, '2017-02-18 00:00:00', '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', 'None', 10.89),
#  (31, 3, '2017-02-21 00:00:00', '1498 rue Bélanger', 'Montréal', 'QC', 'Canada', 'H2G 1A7', 19.8),
#  (32, 30, '2017-02-21 00:00:00', '230 Elgin Street', 'Ottawa', 'ON', 'Canada', 'K2P 1L7', 12.87),
#  (33, 58, '2017-02-21 00:00:00', '12,Community Centre', 'Delhi', 'None', 'India', '110017', 3.96),
#  (34, 33, '2017-02-23 00:00:00', '5112 48 Street', 'Yellowknife', 'NT', 'Canada', 'X1A 1N6', 0.99),
#  (35, 34, '2017-02-25 00:00:00', 'Rua da Assunção 53', 'Lisbon', 'None', 'Portugal', 'None', 4.95),
#  (36, 51, '2017-02-27 00:00:00', 'Celsiusg. 9', 'Stockholm', 'None', 'Sweden', '11230', 6.93),
#  (37, 59, '2017-03-05 00:00:00', '3,Raj Bhavan Road', 'Bangalore', 'None', 'India', '560001', 9.9),
#  (38, 49, '2017-03-05 00:00:00', 'Ordynacka 10', 'Warsaw', 'None', 'Poland', '00-358', 6.93),
#  (39, 39, '2017-03-12 00:00:00', '4, Rue Milton', 'Paris', 'None', 'France', '75009', 7.92),
#  (40, 37, '2017-03-13 00:00:00', 'Berger Straße 10', 'Frankfurt', 'None', 'Germany', '60316', 9.9),
#  (41, 50, '2017-03-17 00:00:00', 'C/ San Bernardo 85', 'Madrid', 'None', 'Spain', '28015', 7.92),
#  (42, 19, '2017-03-18 00:00:00', '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', 8.91),
#  (43, 22, '2017-03-19 00:00:00', '120 S Orange Ave', 'Orlando', 'FL', 'USA', '32801', 6.93),
#  (44, 21, '2017-03-20 00:00:00', '801 W 4th Street', 'Reno', 'NV', 'USA', '89503', 11.879999999999999),
#  (45, 36, '2017-03-24 00:00:00', 'Tauentzienstraße 8', 'Berlin', 'None', 'Germany', '10789', 7.92),
#  (46, 4, '2017-03-24 00:00:00', 'Ullevålsveien 14', 'Oslo', 'None', 'Norway', '0171', 10.89),
#  (47, 57, '2017-03-25 00:00:00', 'Calle Lira, 198', 'Santiago', 'None', 'Chile', 'None', 5.9399999999999995),
#  (48, 44, '2017-03-28 00:00:00', 'Porthaninkatu 9', 'Helsinki', 'None', 'Finland', '00530', 3.96),
#  (49, 10, '2017-03-30 00:00:00', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', 4.95),
#  (50, 18, '2017-04-02 00:00:00', '627 Broadway', 'New York', 'NY', 'USA', '10012-2612', 6.93),
#  (51, 19, '2017-04-03 00:00:00', '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', 7.92),
#  (52, 19, '2017-04-11 00:00:00', '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', 11.879999999999999),
#  (53, 43, '2017-04-12 00:00:00', '68, Rue Jouvence', 'Dijon', 'None', 'France', '21000', 2.9699999999999998),
#  (54, 26, '2017-04-13 00:00:00', '2211 W Berry Street', 'Fort Worth', 'TX', 'USA', '76110', 17.82),
#  (55, 33, '2017-04-16 00:00:00', '5112 48 Street', 'Yellowknife', 'NT', 'Canada', 'X1A 1N6', 9.9),
#  (56, 34, '2017-04-22 00:00:00', 'Rua da Assunção 53', 'Lisbon', 'None', 'Portugal', 'None', 16.83),
#  (57, 19, '2017-04-22 00:00:00', '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', 0.99),
#  (58, 9, '2017-04-23 00:00:00', 'Sønder Boulevard 51', 'Copenhagen', 'None', 'Denmark', '1720', 5.9399999999999995),
#  (59, 38, '2017-04-24 00:00:00', 'Barbarossastraße 19', 'Berlin', 'None', 'Germany', '10779', 10.89),
#  (60, 15, '2017-04-24 00:00:00', '700 W Pender Street', 'Vancouver', 'BC', 'Canada', 'V6C 1G8', 7.92),
#  (61, 59, '2017-04-24 00:00:00', '3,Raj Bhavan Road', 'Bangalore', 'None', 'India', '560001', 11.879999999999999),
#  (62, 9, '2017-04-25 00:00:00', 'Sønder Boulevard 51', 'Copenhagen', 'None', 'Denmark', '1720', 2.9699999999999998),
#  (63, 31, '2017-04-25 00:00:00', '194A Chain Lake Drive', 'Halifax', 'NS', 'Canada', 'B3S 1C5', 5.9399999999999995),
#  (64, 52, '2017-04-25 00:00:00', '202 Hoxton Street', 'London', 'None', 'United Kingdom', 'N1 5LH', 12.87),
#  (65, 47, '2017-04-26 00:00:00', 'Via Degli Scipioni, 43', 'Rome', 'RM', 'Italy', '00192', 1.98),
#  (66, 16, '2017-04-29 00:00:00', '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', 6.93),
#  (67, 39, '2017-05-01 00:00:00', '4, Rue Milton', 'Paris', 'None', 'France', '75009', 10.89),
#  (68, 57, '2017-05-01 00:00:00', 'Calle Lira, 198', 'Santiago', 'None', 'Chile', 'None', 10.89),
#  (69, 2, '2017-05-09 00:00:00', 'Theodor-Heuss-Straße 34', 'Stuttgart', 'None', 'Germany', '70174', 13.86),
#  (70, 31, '2017-05-13 00:00:00', '194A Chain Lake Drive', 'Halifax', 'NS', 'Canada', 'B3S 1C5', 0.99),
#  (71, 3, '2017-05-17 00:00:00', '1498 rue Bélanger', 'Montréal', 'QC', 'Canada', 'H2G 1A7', 16.83),
#  (72, 47, '2017-05-18 00:00:00', 'Via Degli Scipioni, 43', 'Rome', 'RM', 'Italy', '00192', 2.9699999999999998),
#  (73, 13, '2017-05-18 00:00:00', 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', 14.85),
#  (74, 26, '2017-05-18 00:00:00', '2211 W Berry Street', 'Fort Worth', 'TX', 'USA', '76110', 1.98),
#  (75, 16, '2017-05-24 00:00:00', '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', 3.96),
#  (76, 40, '2017-05-26 00:00:00', '8, Rue Hanovre', 'Paris', 'None', 'France', '75002', 12.87),
#  (77, 1, '2017-05-28 00:00:00', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', 5.9399999999999995),
#  (78, 5, '2017-05-29 00:00:00', 'Klanova 9/506', 'Prague', 'None', 'Czech Republic', '14700', 8.91),
#  (79, 36, '2017-06-08 00:00:00', 'Tauentzienstraße 8', 'Berlin', 'None', 'Germany', '10789', 13.86),
#  (80, 13, '2017-06-08 00:00:00', 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', 0.99),
#  (81, 4, '2017-06-12 00:00:00', 'Ullevålsveien 14', 'Oslo', 'None', 'Norway', '0171', 5.9399999999999995),
#  (82, 58, '2017-06-13 00:00:00', '12,Community Centre', 'Delhi', 'None', 'India', '110017', 6.93),
#  (83, 22, '2017-06-15 00:00:00', '120 S Orange Ave', 'Orlando', 'FL', 'USA', '32801', 3.96),
#  (84, 48, '2017-06-15 00:00:00', 'Lijnbaansgracht 120bg', 'Amsterdam', 'VV', 'Netherlands', '1016', 11.879999999999999),
#  (85, 33, '2017-06-17 00:00:00', '5112 48 Street', 'Yellowknife', 'NT', 'Canada', 'X1A 1N6', 4.95),
#  (86, 46, '2017-06-18 00:00:00', '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', 'None', 0.99),
#  (87, 30, '2017-06-20 00:00:00', '230 Elgin Street', 'Ottawa', 'ON', 'Canada', 'K2P 1L7', 7.92),
#  (88, 31, '2017-06-21 00:00:00', '194A Chain Lake Drive', 'Halifax', 'NS', 'Canada', 'B3S 1C5', 4.95),
#  (89, 21, '2017-06-23 00:00:00', '801 W 4th Street', 'Reno', 'NV', 'USA', '89503', 1.98),
#  (90, 55, '2017-06-28 00:00:00', '421 Bourke Street', 'Sidney', 'NSW', 'Australia', '2010', 10.89),
#  (91, 36, '2017-07-01 00:00:00', 'Tauentzienstraße 8', 'Berlin', 'None', 'Germany', '10789', 10.89),
#  (92, 32, '2017-07-02 00:00:00', '696 Osborne Street', 'Winnipeg', 'MB', 'Canada', 'R3L 2B9', 19.8),
#  (93, 42, '2017-07-05 00:00:00', '9, Place Louis Barthou', 'Bordeaux', 'None', 'France', '33000', 9.9),
#  (94, 51, '2017-07-08 00:00:00', 'Celsiusg. 9', 'Stockholm', 'None', 'Sweden', '11230', 7.92),
#  (95, 45, '2017-07-10 00:00:00', 'Erzsébet krt. 58.', 'Budapest', 'None', 'Hungary', 'H-1073', 10.89),
#  (96, 53, '2017-07-17 00:00:00', '113 Lupus St', 'London', 'None', 'United Kingdom', 'SW1V 3EN', 5.9399999999999995),
#  (97, 8, '2017-07-22 00:00:00', 'Grétrystraat 63', 'Brussels', 'None', 'Belgium', '1000', 5.9399999999999995),
#  (98, 17, '2017-07-23 00:00:00', '1 Microsoft Way', 'Redmond', 'WA', 'USA', '98052-8300', 9.9),
#  (99, 55, '2017-07-28 00:00:00', '421 Bourke Street', 'Sidney', 'NSW', 'Australia', '2010', 17.82),
#  (100, 58, '2017-07-31 00:00:00', '12,Community Centre', 'Delhi', 'None', 'India', '110017', 5.9399999999999995),
#  (101, 20, '2017-07-31 00:00:00', '541 Del Medio Avenue', 'Mountain View', 'CA', 'USA', '94040-111', 3.96),
#  (102, 8, '2017-08-02 00:00:00', 'Grétrystraat 63', 'Brussels', 'None', 'Belgium', '1000', 9.9),
#  (103, 39, '2017-08-03 00:00:00', '4, Rue Milton', 'Paris', 'None', 'France', '75009', 5.9399999999999995),
#  (104, 4, '2017-08-06 00:00:00', 'Ullevålsveien 14', 'Oslo', 'None', 'Norway', '0171', 1.98),
#  (105, 31, '2017-08-12 00:00:00', '194A Chain Lake Drive', 'Halifax', 'NS', 'Canada', 'B3S 1C5', 7.92),
#  (106, 54, '2017-08-19 00:00:00', '110 Raeburn Pl', 'Edinburgh ', 'None', 'United Kingdom', 'EH4 1HH', 7.92),
#  (107, 32, '2017-08-21 00:00:00', '696 Osborne Street', 'Winnipeg', 'MB', 'Canada', 'R3L 2B9', 10.89),
#  (108, 30, '2017-08-27 00:00:00', '230 Elgin Street', 'Ottawa', 'ON', 'Canada', 'K2P 1L7', 4.95),
#  (109, 22, '2017-08-29 00:00:00', '120 S Orange Ave', 'Orlando', 'FL', 'USA', '32801', 10.89),
#  (110, 15, '2017-08-29 00:00:00', '700 W Pender Street', 'Vancouver', 'BC', 'Canada', 'V6C 1G8', 5.9399999999999995),
#  (111, 13, '2017-08-30 00:00:00', 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', 4.95),
#  (112, 6, '2017-08-31 00:00:00', 'Rilská 3174/6', 'Prague', 'None', 'Czech Republic', '14300', 16.83),
#  (113, 13, '2017-09-01 00:00:00', 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', 9.9),
#  (114, 12, '2017-09-05 00:00:00', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', 16.83),
#  (115, 50, '2017-09-08 00:00:00', 'C/ San Bernardo 85', 'Madrid', 'None', 'Spain', '28015', 8.91),
#  (116, 6, '2017-09-08 00:00:00', 'Rilská 3174/6', 'Prague', 'None', 'Czech Republic', '14300', 10.89),
#  (117, 44, '2017-09-10 00:00:00', 'Porthaninkatu 9', 'Helsinki', 'None', 'Finland', '00530', 10.89),
#  (118, 28, '2017-09-10 00:00:00', '302 S 700 E', 'Salt Lake City', 'UT', 'USA', '84102', 0.99),
#  (119, 5, '2017-09-12 00:00:00', 'Klanova 9/506', 'Prague', 'None', 'Czech Republic', '14700', 1.98),
#  (120, 29, '2017-09-19 00:00:00', '796 Dundas Street West', 'Toronto', 'ON', 'Canada', 'M6J 1V1', 5.9399999999999995),
#  (121, 59, '2017-09-20 00:00:00', '3,Raj Bhavan Road', 'Bangalore', 'None', 'India', '560001', 8.91),
#  (122, 9, '2017-09-21 00:00:00', 'Sønder Boulevard 51', 'Copenhagen', 'None', 'Denmark', '1720', 4.95),
#  (123, 7, '2017-09-23 00:00:00', 'Rotenturmstraße 4, 1010 Innere Stadt', 'Vienne', 'None', 'Austria', '1010', 11.879999999999999),
#  (124, 8, '2017-09-25 00:00:00', 'Grétrystraat 63', 'Brussels', 'None', 'Belgium', '1000', 5.9399999999999995),
#  (125, 3, '2017-09-29 00:00:00', '1498 rue Bélanger', 'Montréal', 'QC', 'Canada', 'H2G 1A7', 9.9),
#  (126, 32, '2017-10-07 00:00:00', '696 Osborne Street', 'Winnipeg', 'MB', 'Canada', 'R3L 2B9', 3.96),
#  (127, 35, '2017-10-08 00:00:00', 'Rua dos Campeões Europeus de Viena, 4350', 'Porto', 'None', 'Portugal', 'None', 10.89),
#  (128, 17, '2017-10-12 00:00:00', '1 Microsoft Way', 'Redmond', 'WA', 'USA', '98052-8300', 6.93),
#  (129, 17, '2017-10-16 00:00:00', '1 Microsoft Way', 'Redmond', 'WA', 'USA', '98052-8300', 10.89),
#  (130, 13, '2017-10-19 00:00:00', 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', 3.96),
#  (131, 2, '2017-10-21 00:00:00', 'Theodor-Heuss-Straße 34', 'Stuttgart', 'None', 'Germany', '70174', 2.9699999999999998),
#  (132, 14, '2017-10-22 00:00:00', '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', 1.98),
#  (133, 35, '2017-10-22 00:00:00', 'Rua dos Campeões Europeus de Viena, 4350', 'Porto', 'None', 'Portugal', 'None', 9.9),
#  (134, 2, '2017-10-23 00:00:00', 'Theodor-Heuss-Straße 34', 'Stuttgart', 'None', 'Germany', '70174', 7.92),
#  (135, 11, '2017-10-25 00:00:00', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', 2.9699999999999998),
#  (136, 33, '2017-10-29 00:00:00', '5112 48 Street', 'Yellowknife', 'NT', 'Canada', 'X1A 1N6', 3.96),
#  (137, 34, '2017-10-29 00:00:00', 'Rua da Assunção 53', 'Lisbon', 'None', 'Portugal', 'None', 1.98),
#  (138, 33, '2017-10-30 00:00:00', '5112 48 Street', 'Yellowknife', 'NT', 'Canada', 'X1A 1N6', 10.89),
#  (139, 23, '2017-11-03 00:00:00', '69 Salem Street', 'Boston', 'MA', 'USA', '2113', 4.95),
#  (140, 58, '2017-11-06 00:00:00', '12,Community Centre', 'Delhi', 'None', 'India', '110017', 7.92),
#  (141, 45, '2017-11-07 00:00:00', 'Erzsébet krt. 58.', 'Budapest', 'None', 'Hungary', 'H-1073', 17.82),
#  (142, 15, '2017-11-10 00:00:00', '700 W Pender Street', 'Vancouver', 'BC', 'Canada', 'V6C 1G8', 14.85),
#  (143, 25, '2017-11-10 00:00:00', '319 N. Frances Street', 'Madison', 'WI', 'USA', '53703', 4.95),
#  (144, 33, '2017-11-18 00:00:00', '5112 48 Street', 'Yellowknife', 'NT', 'Canada', 'X1A 1N6', 2.9699999999999998),
#  (145, 28, '2017-11-22 00:00:00', '302 S 700 E', 'Salt Lake City', 'UT', 'USA', '84102', 4.95),
#  (146, 58, '2017-11-22 00:00:00', '12,Community Centre', 'Delhi', 'None', 'India', '110017', 12.87),
#  (147, 19, '2017-11-28 00:00:00', '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', 4.95),
#  (148, 42, '2017-11-30 00:00:00', '9, Place Louis Barthou', 'Bordeaux', 'None', 'France', '33000', 8.91),
#  (149, 1, '2017-11-30 00:00:00', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', 8.91),
#  (150, 22, '2017-12-01 00:00:00', '120 S Orange Ave', 'Orlando', 'FL', 'USA', '32801', 2.9699999999999998),
#  (151, 35, '2017-12-06 00:00:00', 'Rua dos Campeões Europeus de Viena, 4350', 'Porto', 'None', 'Portugal', 'None', 2.9699999999999998),
#  (152, 12, '2017-12-12 00:00:00', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', 5.9399999999999995),
#  (153, 1, '2017-12-14 00:00:00', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', 13.86),
#  (154, 39, '2017-12-17 00:00:00', '4, Rue Milton', 'Paris', 'None', 'France', '75009', 2.9699999999999998),
#  (155, 59, '2018-01-02 00:00:00', '3,Raj Bhavan Road', 'Bangalore', 'None', 'India', '560001', 8.91),
#  (156, 10, '2018-01-03 00:00:00', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', 10.89),
#  (157, 57, '2018-01-04 00:00:00', 'Calle Lira, 198', 'Santiago', 'None', 'Chile', 'None', 0.99),
#  (158, 57, '2018-01-07 00:00:00', 'Calle Lira, 198', 'Santiago', 'None', 'Chile', 'None', 5.9399999999999995),
#  (159, 20, '2018-01-08 00:00:00', '541 Del Medio Avenue', 'Mountain View', 'CA', 'USA', '94040-111', 5.9399999999999995),
#  (160, 41, '2018-01-09 00:00:00', '11, Place Bellecour', 'Lyon', 'None', 'France', '69002', 8.91),
#  (161, 24, '2018-01-13 00:00:00', '162 E Superior Street', 'Chicago', 'IL', 'USA', '60611', 7.92),
#  (162, 2, '2018-01-15 00:00:00', 'Theodor-Heuss-Straße 34', 'Stuttgart', 'None', 'Germany', '70174', 8.91),
#  (163, 6, '2018-01-16 00:00:00', 'Rilská 3174/6', 'Prague', 'None', 'Czech Republic', '14300', 8.91),
#  (164, 49, '2018-01-20 00:00:00', 'Ordynacka 10', 'Warsaw', 'None', 'Poland', '00-358', 3.96),
#  (165, 41, '2018-01-21 00:00:00', '11, Place Bellecour', 'Lyon', 'None', 'France', '69002', 7.92),
#  (166, 17, '2018-01-21 00:00:00', '1 Microsoft Way', 'Redmond', 'WA', 'USA', '98052-8300', 9.9),
#  (167, 21, '2018-01-25 00:00:00', '801 W 4th Street', 'Reno', 'NV', 'USA', '89503', 5.9399999999999995),
#  (168, 47, '2018-01-27 00:00:00', 'Via Degli Scipioni, 43', 'Rome', 'RM', 'Italy', '00192', 5.9399999999999995),
#  (169, 21, '2018-01-28 00:00:00', '801 W 4th Street', 'Reno', 'NV', 'USA', '89503', 8.91),
#  (170, 45, '2018-01-28 00:00:00', 'Erzsébet krt. 58.', 'Budapest', 'None', 'Hungary', 'H-1073', 9.9),
#  (171, 53, '2018-01-30 00:00:00', '113 Lupus St', 'London', 'None', 'United Kingdom', 'SW1V 3EN', 12.87),
#  (172, 33, '2018-01-31 00:00:00', '5112 48 Street', 'Yellowknife', 'NT', 'Canada', 'X1A 1N6', 7.92),
#  (173, 5, '2018-01-31 00:00:00', 'Klanova 9/506', 'Prague', 'None', 'Czech Republic', '14700', 10.89),
#  (174, 48, '2018-01-31 00:00:00', 'Lijnbaansgracht 120bg', 'Amsterdam', 'VV', 'Netherlands', '1016', 6.93),
#  (175, 39, '2018-01-31 00:00:00', '4, Rue Milton', 'Paris', 'None', 'France', '75009', 17.82),
#  (176, 46, '2018-01-31 00:00:00', '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', 'None', 6.93),
#  (177, 47, '2018-02-01 00:00:00', 'Via Degli Scipioni, 43', 'Rome', 'RM', 'Italy', '00192', 1.98),
#  (178, 9, '2018-02-02 00:00:00', 'Sønder Boulevard 51', 'Copenhagen', 'None', 'Denmark', '1720', 2.9699999999999998),
#  (179, 25, '2018-02-03 00:00:00', '319 N. Frances Street', 'Madison', 'WI', 'USA', '53703', 9.9),
#  (180, 46, '2018-02-05 00:00:00', '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', 'None', 9.9),
#  (181, 45, '2018-02-06 00:00:00', 'Erzsébet krt. 58.', 'Budapest', 'None', 'Hungary', 'H-1073', 6.93),
#  (182, 1, '2018-02-07 00:00:00', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', 5.9399999999999995),
#  (183, 42, '2018-02-09 00:00:00', '9, Place Louis Barthou', 'Bordeaux', 'None', 'France', '33000', 23.759999999999998),
#  (184, 1, '2018-02-09 00:00:00', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', 0.99),
#  (185, 21, '2018-02-10 00:00:00', '801 W 4th Street', 'Reno', 'NV', 'USA', '89503', 8.91),
#  (186, 11, '2018-02-10 00:00:00', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', 2.9699999999999998),
#  (187, 18, '2018-02-18 00:00:00', '627 Broadway', 'New York', 'NY', 'USA', '10012-2612', 6.93),
#  (188, 13, '2018-02-20 00:00:00', 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', 10.89),
#  (189, 13, '2018-02-21 00:00:00', 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', 3.96),
#  (190, 51, '2018-02-21 00:00:00', 'Celsiusg. 9', 'Stockholm', 'None', 'Sweden', '11230', 4.95),
#  (191, 51, '2018-02-22 00:00:00', 'Celsiusg. 9', 'Stockholm', 'None', 'Sweden', '11230', 3.96),
#  (192, 28, '2018-02-25 00:00:00', '302 S 700 E', 'Salt Lake City', 'UT', 'USA', '84102', 8.91),
#  (193, 41, '2018-02-26 00:00:00', '11, Place Bellecour', 'Lyon', 'None', 'France', '69002', 1.98),
#  (194, 34, '2018-02-27 00:00:00', 'Rua da Assunção 53', 'Lisbon', 'None', 'Portugal', 'None', 0.99),
#  (195, 27, '2018-03-02 00:00:00', '1033 N Park Ave', 'Tucson', 'AZ', 'USA', '85719', 10.89),
#  (196, 37, '2018-03-02 00:00:00', 'Berger Straße 10', 'Frankfurt', 'None', 'Germany', '60316', 9.9),
#  (197, 46, '2018-03-05 00:00:00', '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', 'None', 10.89),
#  (198, 13, '2018-03-05 00:00:00', 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', 10.89),
#  (199, 20, '2018-03-08 00:00:00', '541 Del Medio Avenue', 'Mountain View', 'CA', 'USA', '94040-111', 2.9699999999999998),
#  (200, 24, '2018-03-08 00:00:00', '162 E Superior Street', 'Chicago', 'IL', 'USA', '60611', 7.92),
#  (201, 39, '2018-03-11 00:00:00', '4, Rue Milton', 'Paris', 'None', 'France', '75009', 11.879999999999999),
#  (202, 25, '2018-03-13 00:00:00', '319 N. Frances Street', 'Madison', 'WI', 'USA', '53703', 1.98),
#  (203, 38, '2018-03-16 00:00:00', 'Barbarossastraße 19', 'Berlin', 'None', 'Germany', '10779', 9.9),
#  (204, 20, '2018-03-17 00:00:00', '541 Del Medio Avenue', 'Mountain View', 'CA', 'USA', '94040-111', 10.89),
#  (205, 4, '2018-03-20 00:00:00', 'Ullevålsveien 14', 'Oslo', 'None', 'Norway', '0171', 9.9),
#  (206, 11, '2018-03-21 00:00:00', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', 4.95),
#  (207, 17, '2018-03-21 00:00:00', '1 Microsoft Way', 'Redmond', 'WA', 'USA', '98052-8300', 3.96),
#  (208, 4, '2018-03-22 00:00:00', 'Ullevålsveien 14', 'Oslo', 'None', 'Norway', '0171', 5.9399999999999995),
#  (209, 27, '2018-03-25 00:00:00', '1033 N Park Ave', 'Tucson', 'AZ', 'USA', '85719', 3.96),
#  (210, 2, '2018-03-25 00:00:00', 'Theodor-Heuss-Straße 34', 'Stuttgart', 'None', 'Germany', '70174', 10.89),
#  (211, 51, '2018-03-26 00:00:00', 'Celsiusg. 9', 'Stockholm', 'None', 'Sweden', '11230', 8.91),
#  (212, 45, '2018-03-31 00:00:00', 'Erzsébet krt. 58.', 'Budapest', 'None', 'Hungary', 'H-1073', 11.879999999999999),
#  (213, 53, '2018-04-01 00:00:00', '113 Lupus St', 'London', 'None', 'United Kingdom', 'SW1V 3EN', 10.89),
#  (214, 57, '2018-04-03 00:00:00', 'Calle Lira, 198', 'Santiago', 'None', 'Chile', 'None', 4.95),
#  (215, 26, '2018-04-04 00:00:00', '2211 W Berry Street', 'Fort Worth', 'TX', 'USA', '76110', 1.98),
#  (216, 49, '2018-04-14 00:00:00', 'Ordynacka 10', 'Warsaw', 'None', 'Poland', '00-358', 4.95),
#  (217, 27, '2018-04-17 00:00:00', '1033 N Park Ave', 'Tucson', 'AZ', 'USA', '85719', 9.9),
#  (218, 56, '2018-04-19 00:00:00', '307 Macacha Güemes', 'Buenos Aires', 'None', 'Argentina', '1106', 8.91),
#  (219, 20, '2018-04-21 00:00:00', '541 Del Medio Avenue', 'Mountain View', 'CA', 'USA', '94040-111', 2.9699999999999998),
#  (220, 59, '2018-04-25 00:00:00', '3,Raj Bhavan Road', 'Bangalore', 'None', 'India', '560001', 8.91),
#  (221, 35, '2018-04-25 00:00:00', 'Rua dos Campeões Europeus de Viena, 4350', 'Porto', 'None', 'Portugal', 'None', 7.92),
#  (222, 2, '2018-04-29 00:00:00', 'Theodor-Heuss-Straße 34', 'Stuttgart', 'None', 'Germany', '70174', 1.98),
#  (223, 1, '2018-05-04 00:00:00', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', 17.82),
#  (224, 34, '2018-05-06 00:00:00', 'Rua da Assunção 53', 'Lisbon', 'None', 'Portugal', 'None', 9.9),
#  (225, 7, '2018-05-08 00:00:00', 'Rotenturmstraße 4, 1010 Innere Stadt', 'Vienne', 'None', 'Austria', '1010', 5.9399999999999995),
#  (226, 42, '2018-05-12 00:00:00', '9, Place Louis Barthou', 'Bordeaux', 'None', 'France', '33000', 10.89),
#  (227, 52, '2018-05-16 00:00:00', '202 Hoxton Street', 'London', 'None', 'United Kingdom', 'N1 5LH', 9.9),
#  (228, 57, '2018-05-16 00:00:00', 'Calle Lira, 198', 'Santiago', 'None', 'Chile', 'None', 3.96),
#  (229, 15, '2018-05-19 00:00:00', '700 W Pender Street', 'Vancouver', 'BC', 'Canada', 'V6C 1G8', 2.9699999999999998),
#  (230, 54, '2018-05-21 00:00:00', '110 Raeburn Pl', 'Edinburgh ', 'None', 'United Kingdom', 'EH4 1HH', 7.92),
#  (231, 19, '2018-05-27 00:00:00', '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', 2.9699999999999998),
#  (232, 57, '2018-05-29 00:00:00', 'Calle Lira, 198', 'Santiago', 'None', 'Chile', 'None', 3.96),
#  (233, 14, '2018-06-01 00:00:00', '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', 5.9399999999999995),
#  (234, 36, '2018-06-01 00:00:00', 'Tauentzienstraße 8', 'Berlin', 'None', 'Germany', '10789', 0.99),
#  (235, 5, '2018-06-06 00:00:00', 'Klanova 9/506', 'Prague', 'None', 'Czech Republic', '14700', 6.93),
#  (236, 35, '2018-06-08 00:00:00', 'Rua dos Campeões Europeus de Viena, 4350', 'Porto', 'None', 'Portugal', 'None', 2.9699999999999998),
#  (237, 52, '2018-06-13 00:00:00', '202 Hoxton Street', 'London', 'None', 'United Kingdom', 'N1 5LH', 15.84),
#  (238, 46, '2018-06-14 00:00:00', '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', 'None', 9.9),
#  (239, 38, '2018-06-16 00:00:00', 'Barbarossastraße 19', 'Berlin', 'None', 'Germany', '10779', 15.84),
#  (240, 10, '2018-06-17 00:00:00', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', 2.9699999999999998),
#  (241, 45, '2018-06-18 00:00:00', 'Erzsébet krt. 58.', 'Budapest', 'None', 'Hungary', 'H-1073', 1.98),
#  (242, 36, '2018-06-18 00:00:00', 'Tauentzienstraße 8', 'Berlin', 'None', 'Germany', '10789', 9.9),
#  (243, 6, '2018-06-23 00:00:00', 'Rilská 3174/6', 'Prague', 'None', 'Czech Republic', '14300', 10.89),
#  (244, 53, '2018-06-23 00:00:00', '113 Lupus St', 'London', 'None', 'United Kingdom', 'SW1V 3EN', 4.95),
#  (245, 20, '2018-06-30 00:00:00', '541 Del Medio Avenue', 'Mountain View', 'CA', 'USA', '94040-111', 2.9699999999999998),
#  (246, 58, '2018-07-12 00:00:00', '12,Community Centre', 'Delhi', 'None', 'India', '110017', 8.91),
#  (247, 27, '2018-07-12 00:00:00', '1033 N Park Ave', 'Tucson', 'AZ', 'USA', '85719', 10.89),
#  (248, 3, '2018-07-13 00:00:00', '1498 rue Bélanger', 'Montréal', 'QC', 'Canada', 'H2G 1A7', 6.93),
#  (249, 12, '2018-07-14 00:00:00', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', 1.98),
#  (250, 23, '2018-07-20 00:00:00', '69 Salem Street', 'Boston', 'MA', 'USA', '2113', 10.89),
#  (251, 7, '2018-07-20 00:00:00', 'Rotenturmstraße 4, 1010 Innere Stadt', 'Vienne', 'None', 'Austria', '1010', 6.93),
#  (252, 44, '2018-07-25 00:00:00', 'Porthaninkatu 9', 'Helsinki', 'None', 'Finland', '00530', 7.92),
#  (253, 8, '2018-07-29 00:00:00', 'Grétrystraat 63', 'Brussels', 'None', 'Belgium', '1000', 11.879999999999999),
#  (254, 57, '2018-07-30 00:00:00', 'Calle Lira, 198', 'Santiago', 'None', 'Chile', 'None', 9.9),
#  (255, 46, '2018-07-31 00:00:00', '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', 'None', 3.96),
#  (256, 13, '2018-07-31 00:00:00', 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', 4.95),
#  (257, 16, '2018-08-01 00:00:00', '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', 10.89),
#  (258, 48, '2018-08-02 00:00:00', 'Lijnbaansgracht 120bg', 'Amsterdam', 'VV', 'Netherlands', '1016', 0.99),
#  (259, 38, '2018-08-03 00:00:00', 'Barbarossastraße 19', 'Berlin', 'None', 'Germany', '10779', 6.93),
#  (260, 10, '2018-08-04 00:00:00', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', 7.92),
#  (261, 49, '2018-08-06 00:00:00', 'Ordynacka 10', 'Warsaw', 'None', 'Poland', '00-358', 8.91),
#  (262, 3, '2018-08-09 00:00:00', '1498 rue Bélanger', 'Montréal', 'QC', 'Canada', 'H2G 1A7', 7.92),
#  (263, 36, '2018-08-13 00:00:00', 'Tauentzienstraße 8', 'Berlin', 'None', 'Germany', '10789', 4.95),
#  (264, 38, '2018-08-15 00:00:00', 'Barbarossastraße 19', 'Berlin', 'None', 'Germany', '10779', 0.99),
#  (265, 52, '2018-08-18 00:00:00', '202 Hoxton Street', 'London', 'None', 'United Kingdom', 'N1 5LH', 6.93),
#  (266, 44, '2018-08-22 00:00:00', 'Porthaninkatu 9', 'Helsinki', 'None', 'Finland', '00530', 5.9399999999999995),
#  (267, 9, '2018-08-22 00:00:00', 'Sønder Boulevard 51', 'Copenhagen', 'None', 'Denmark', '1720', 1.98),
#  (268, 16, '2018-08-23 00:00:00', '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', 10.89),
#  (269, 43, '2018-08-26 00:00:00', '68, Rue Jouvence', 'Dijon', 'None', 'France', '21000', 0.99),
#  (270, 1, '2018-08-27 00:00:00', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', 10.89),
#  (271, 47, '2018-08-30 00:00:00', 'Via Degli Scipioni, 43', 'Rome', 'RM', 'Italy', '00192', 10.89),
#  (272, 4, '2018-08-30 00:00:00', 'Ullevålsveien 14', 'Oslo', 'None', 'Norway', '0171', 8.91),
#  (273, 37, '2018-09-02 00:00:00', 'Berger Straße 10', 'Frankfurt', 'None', 'Germany', '60316', 16.83),
#  (274, 26, '2018-09-04 00:00:00', '2211 W Berry Street', 'Fort Worth', 'TX', 'USA', '76110', 4.95),
#  (275, 6, '2018-09-06 00:00:00', 'Rilská 3174/6', 'Prague', 'None', 'Czech Republic', '14300', 7.92),
#  (276, 22, '2018-09-07 00:00:00', '120 S Orange Ave', 'Orlando', 'FL', 'USA', '32801', 18.81),
#  (277, 53, '2018-09-10 00:00:00', '113 Lupus St', 'London', 'None', 'United Kingdom', 'SW1V 3EN', 4.95),
#  (278, 22, '2018-09-23 00:00:00', '120 S Orange Ave', 'Orlando', 'FL', 'USA', '32801', 2.9699999999999998),
#  (279, 41, '2018-10-01 00:00:00', '11, Place Bellecour', 'Lyon', 'None', 'France', '69002', 4.95),
#  (280, 6, '2018-10-02 00:00:00', 'Rilská 3174/6', 'Prague', 'None', 'Czech Republic', '14300', 10.89),
#  (281, 50, '2018-10-06 00:00:00', 'C/ San Bernardo 85', 'Madrid', 'None', 'Spain', '28015', 13.86),
#  (282, 20, '2018-10-11 00:00:00', '541 Del Medio Avenue', 'Mountain View', 'CA', 'USA', '94040-111', 16.83),
#  (283, 48, '2018-10-13 00:00:00', 'Lijnbaansgracht 120bg', 'Amsterdam', 'VV', 'Netherlands', '1016', 8.91),
#  (284, 49, '2018-10-16 00:00:00', 'Ordynacka 10', 'Warsaw', 'None', 'Poland', '00-358', 10.89),
#  (285, 58, '2018-10-25 00:00:00', '12,Community Centre', 'Delhi', 'None', 'India', '110017', 9.9),
#  (286, 27, '2018-10-25 00:00:00', '1033 N Park Ave', 'Tucson', 'AZ', 'USA', '85719', 1.98),
#  (287, 23, '2018-11-04 00:00:00', '69 Salem Street', 'Boston', 'MA', 'USA', '2113', 1.98),
#  (288, 17, '2018-11-04 00:00:00', '1 Microsoft Way', 'Redmond', 'WA', 'USA', '98052-8300', 10.89),
#  (289, 16, '2018-11-06 00:00:00', '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', 6.93),
#  (290, 17, '2018-11-18 00:00:00', '1 Microsoft Way', 'Redmond', 'WA', 'USA', '98052-8300', 4.95),
#  (291, 35, '2018-11-19 00:00:00', 'Rua dos Campeões Europeus de Viena, 4350', 'Porto', 'None', 'Portugal', 'None', 2.9699999999999998),
#  (292, 4, '2018-11-21 00:00:00', 'Ullevålsveien 14', 'Oslo', 'None', 'Norway', '0171', 9.9),
#  (293, 14, '2018-11-29 00:00:00', '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', 4.95),
#  (294, 58, '2018-12-02 00:00:00', '12,Community Centre', 'Delhi', 'None', 'India', '110017', 10.89),
#  (295, 33, '2018-12-03 00:00:00', '5112 48 Street', 'Yellowknife', 'NT', 'Canada', 'X1A 1N6', 0.99),
#  (296, 1, '2018-12-10 00:00:00', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', 12.87),
#  (297, 22, '2018-12-11 00:00:00', '120 S Orange Ave', 'Orlando', 'FL', 'USA', '32801', 2.9699999999999998),
#  (298, 12, '2018-12-13 00:00:00', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', 8.91),
#  (299, 30, '2018-12-14 00:00:00', '230 Elgin Street', 'Ottawa', 'ON', 'Canada', 'K2P 1L7', 5.9399999999999995),
#  (300, 25, '2018-12-15 00:00:00', '319 N. Frances Street', 'Madison', 'WI', 'USA', '53703', 11.879999999999999),
#  (301, 34, '2018-12-15 00:00:00', 'Rua da Assunção 53', 'Lisbon', 'None', 'Portugal', 'None', 7.92),
#  (302, 40, '2018-12-18 00:00:00', '8, Rue Hanovre', 'Paris', 'None', 'France', '75002', 3.96),
#  (303, 28, '2018-12-21 00:00:00', '302 S 700 E', 'Salt Lake City', 'UT', 'USA', '84102', 9.9),
#  (304, 56, '2018-12-23 00:00:00', '307 Macacha Güemes', 'Buenos Aires', 'None', 'Argentina', '1106', 6.93),
#  (305, 40, '2018-12-26 00:00:00', '8, Rue Hanovre', 'Paris', 'None', 'France', '75002', 14.85),
#  (306, 8, '2019-01-01 00:00:00', 'Grétrystraat 63', 'Brussels', 'None', 'Belgium', '1000', 10.89),
#  (307, 26, '2019-01-05 00:00:00', '2211 W Berry Street', 'Fort Worth', 'TX', 'USA', '76110', 9.9),
#  (308, 37, '2019-01-06 00:00:00', 'Berger Straße 10', 'Frankfurt', 'None', 'Germany', '60316', 10.89),
#  (309, 36, '2019-01-14 00:00:00', 'Tauentzienstraße 8', 'Berlin', 'None', 'Germany', '10789', 8.91),
#  (310, 22, '2019-01-16 00:00:00', '120 S Orange Ave', 'Orlando', 'FL', 'USA', '32801', 8.91),
#  (311, 8, '2019-01-18 00:00:00', 'Grétrystraat 63', 'Brussels', 'None', 'Belgium', '1000', 5.9399999999999995),
#  (312, 42, '2019-01-21 00:00:00', '9, Place Louis Barthou', 'Bordeaux', 'None', 'France', '33000', 9.9),
#  (313, 30, '2019-01-24 00:00:00', '230 Elgin Street', 'Ottawa', 'ON', 'Canada', 'K2P 1L7', 4.95),
#  (314, 43, '2019-01-29 00:00:00', '68, Rue Jouvence', 'Dijon', 'None', 'France', '21000', 9.9),
#  (315, 10, '2019-01-30 00:00:00', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', 4.95),
#  (316, 11, '2019-02-03 00:00:00', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', 1.98),
#  (317, 40, '2019-02-14 00:00:00', '8, Rue Hanovre', 'Paris', 'None', 'France', '75002', 11.879999999999999),
#  (318, 43, '2019-02-19 00:00:00', '68, Rue Jouvence', 'Dijon', 'None', 'France', '21000', 7.92),
#  (319, 50, '2019-02-20 00:00:00', 'C/ San Bernardo 85', 'Madrid', 'None', 'Spain', '28015', 9.9),
#  (320, 58, '2019-02-22 00:00:00', '12,Community Centre', 'Delhi', 'None', 'India', '110017', 16.83),
#  (321, 14, '2019-02-23 00:00:00', '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', 0.99),
#  (322, 21, '2019-02-24 00:00:00', '801 W 4th Street', 'Reno', 'NV', 'USA', '89503', 9.9),
#  (323, 23, '2019-03-03 00:00:00', '69 Salem Street', 'Boston', 'MA', 'USA', '2113', 7.92),
#  (324, 57, '2019-03-03 00:00:00', 'Calle Lira, 198', 'Santiago', 'None', 'Chile', 'None', 4.95),
#  (325, 33, '2019-03-04 00:00:00', '5112 48 Street', 'Yellowknife', 'NT', 'Canada', 'X1A 1N6', 9.9),
#  (326, 52, '2019-03-04 00:00:00', '202 Hoxton Street', 'London', 'None', 'United Kingdom', 'N1 5LH', 8.91),
#  (327, 49, '2019-03-05 00:00:00', 'Ordynacka 10', 'Warsaw', 'None', 'Poland', '00-358', 8.91),
#  (328, 10, '2019-03-08 00:00:00', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', 3.96),
#  (329, 9, '2019-03-09 00:00:00', 'Sønder Boulevard 51', 'Copenhagen', 'None', 'Denmark', '1720', 0.99),
#  (330, 22, '2019-03-13 00:00:00', '120 S Orange Ave', 'Orlando', 'FL', 'USA', '32801', 12.87),
#  (331, 25, '2019-03-15 00:00:00', '319 N. Frances Street', 'Madison', 'WI', 'USA', '53703', 5.9399999999999995),
#  (332, 29, '2019-03-15 00:00:00', '796 Dundas Street West', 'Toronto', 'ON', 'Canada', 'M6J 1V1', 9.9),
#  (333, 12, '2019-03-21 00:00:00', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', 5.9399999999999995),
#  (334, 53, '2019-03-21 00:00:00', '113 Lupus St', 'London', 'None', 'United Kingdom', 'SW1V 3EN', 14.85),
#  (335, 57, '2019-03-23 00:00:00', 'Calle Lira, 198', 'Santiago', 'None', 'Chile', 'None', 14.85),
#  (336, 6, '2019-03-31 00:00:00', 'Rilská 3174/6', 'Prague', 'None', 'Czech Republic', '14300', 15.84),
#  (337, 7, '2019-04-03 00:00:00', 'Rotenturmstraße 4, 1010 Innere Stadt', 'Vienne', 'None', 'Austria', '1010', 9.9),
#  (338, 58, '2019-04-03 00:00:00', '12,Community Centre', 'Delhi', 'None', 'India', '110017', 4.95),
#  (339, 36, '2019-04-07 00:00:00', 'Tauentzienstraße 8', 'Berlin', 'None', 'Germany', '10789', 7.92),
#  (340, 48, '2019-04-08 00:00:00', 'Lijnbaansgracht 120bg', 'Amsterdam', 'VV', 'Netherlands', '1016', 2.9699999999999998),
#  (341, 5, '2019-04-09 00:00:00', 'Klanova 9/506', 'Prague', 'None', 'Czech Republic', '14700', 11.879999999999999),
#  (342, 3, '2019-04-13 00:00:00', '1498 rue Bélanger', 'Montréal', 'QC', 'Canada', 'H2G 1A7', 2.9699999999999998),
#  (343, 2, '2019-04-13 00:00:00', 'Theodor-Heuss-Straße 34', 'Stuttgart', 'None', 'Germany', '70174', 5.9399999999999995),
#  (344, 3, '2019-04-15 00:00:00', '1498 rue Bélanger', 'Montréal', 'QC', 'Canada', 'H2G 1A7', 16.83),
#  (345, 50, '2019-04-16 00:00:00', 'C/ San Bernardo 85', 'Madrid', 'None', 'Spain', '28015', 9.9),
#  (346, 40, '2019-04-17 00:00:00', '8, Rue Hanovre', 'Paris', 'None', 'France', '75002', 5.9399999999999995),
#  (347, 44, '2019-04-17 00:00:00', 'Porthaninkatu 9', 'Helsinki', 'None', 'Finland', '00530', 3.96),
#  (348, 35, '2019-04-18 00:00:00', 'Rua dos Campeões Europeus de Viena, 4350', 'Porto', 'None', 'Portugal', 'None', 8.91),
#  (349, 37, '2019-04-21 00:00:00', 'Berger Straße 10', 'Frankfurt', 'None', 'Germany', '60316', 0.99),
#  (350, 44, '2019-04-21 00:00:00', 'Porthaninkatu 9', 'Helsinki', 'None', 'Finland', '00530', 2.9699999999999998),
#  (351, 57, '2019-04-23 00:00:00', 'Calle Lira, 198', 'Santiago', 'None', 'Chile', 'None', 9.9),
#  (352, 10, '2019-04-23 00:00:00', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', 0.99),
#  (353, 28, '2019-04-28 00:00:00', '302 S 700 E', 'Salt Lake City', 'UT', 'USA', '84102', 9.9),
#  (354, 9, '2019-05-02 00:00:00', 'Sønder Boulevard 51', 'Copenhagen', 'None', 'Denmark', '1720', 4.95),
#  (355, 43, '2019-05-04 00:00:00', '68, Rue Jouvence', 'Dijon', 'None', 'France', '21000', 6.93),
#  (356, 55, '2019-05-04 00:00:00', '421 Bourke Street', 'Sidney', 'NSW', 'Australia', '2010', 6.93),
#  (357, 13, '2019-05-08 00:00:00', 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', 2.9699999999999998),
#  (358, 19, '2019-05-12 00:00:00', '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', 6.93),
#  (359, 43, '2019-05-12 00:00:00', '68, Rue Jouvence', 'Dijon', 'None', 'France', '21000', 8.91),
#  (360, 45, '2019-05-15 00:00:00', 'Erzsébet krt. 58.', 'Budapest', 'None', 'Hungary', 'H-1073', 3.96),
#  (361, 5, '2019-05-18 00:00:00', 'Klanova 9/506', 'Prague', 'None', 'Czech Republic', '14700', 1.98),
#  (362, 29, '2019-05-24 00:00:00', '796 Dundas Street West', 'Toronto', 'ON', 'Canada', 'M6J 1V1', 19.8),
#  (363, 38, '2019-05-24 00:00:00', 'Barbarossastraße 19', 'Berlin', 'None', 'Germany', '10779', 2.9699999999999998),
#  (364, 26, '2019-05-26 00:00:00', '2211 W Berry Street', 'Fort Worth', 'TX', 'USA', '76110', 5.9399999999999995),
#  (365, 28, '2019-05-27 00:00:00', '302 S 700 E', 'Salt Lake City', 'UT', 'USA', '84102', 3.96),
#  (366, 26, '2019-05-27 00:00:00', '2211 W Berry Street', 'Fort Worth', 'TX', 'USA', '76110', 8.91),
#  (367, 40, '2019-05-29 00:00:00', '8, Rue Hanovre', 'Paris', 'None', 'France', '75002', 7.92),
#  (368, 35, '2019-05-30 00:00:00', 'Rua dos Campeões Europeus de Viena, 4350', 'Porto', 'None', 'Portugal', 'None', 1.98),
#  (369, 50, '2019-05-31 00:00:00', 'C/ San Bernardo 85', 'Madrid', 'None', 'Spain', '28015', 9.9),
#  (370, 14, '2019-06-01 00:00:00', '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', 8.91),
#  (371, 14, '2019-06-01 00:00:00', '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', 0.99),
#  (372, 18, '2019-06-01 00:00:00', '627 Broadway', 'New York', 'NY', 'USA', '10012-2612', 13.86),
#  (373, 39, '2019-06-01 00:00:00', '4, Rue Milton', 'Paris', 'None', 'France', '75009', 3.96),
#  (374, 43, '2019-06-03 00:00:00', '68, Rue Jouvence', 'Dijon', 'None', 'France', '21000', 5.9399999999999995),
#  (375, 35, '2019-06-05 00:00:00', 'Rua dos Campeões Europeus de Viena, 4350', 'Porto', 'None', 'Portugal', 'None', 8.91),
#  (376, 5, '2019-06-06 00:00:00', 'Klanova 9/506', 'Prague', 'None', 'Czech Republic', '14700', 3.96),
#  (377, 28, '2019-06-09 00:00:00', '302 S 700 E', 'Salt Lake City', 'UT', 'USA', '84102', 2.9699999999999998),
#  (378, 48, '2019-06-13 00:00:00', 'Lijnbaansgracht 120bg', 'Amsterdam', 'VV', 'Netherlands', '1016', 3.96),
#  (379, 54, '2019-06-13 00:00:00', '110 Raeburn Pl', 'Edinburgh ', 'None', 'United Kingdom', 'EH4 1HH', 11.879999999999999),
#  (380, 56, '2019-06-14 00:00:00', '307 Macacha Güemes', 'Buenos Aires', 'None', 'Argentina', '1106', 9.9),
#  (381, 56, '2019-06-21 00:00:00', '307 Macacha Güemes', 'Buenos Aires', 'None', 'Argentina', '1106', 12.87),
#  (382, 48, '2019-06-22 00:00:00', 'Lijnbaansgracht 120bg', 'Amsterdam', 'VV', 'Netherlands', '1016', 3.96),
#  (383, 23, '2019-07-03 00:00:00', '69 Salem Street', 'Boston', 'MA', 'USA', '2113', 9.9),
#  (384, 50, '2019-07-10 00:00:00', 'C/ San Bernardo 85', 'Madrid', 'None', 'Spain', '28015', 10.89),
#  (385, 42, '2019-07-11 00:00:00', '9, Place Louis Barthou', 'Bordeaux', 'None', 'France', '33000', 6.93),
#  (386, 26, '2019-07-12 00:00:00', '2211 W Berry Street', 'Fort Worth', 'TX', 'USA', '76110', 4.95),
#  (387, 6, '2019-07-15 00:00:00', 'Rilská 3174/6', 'Prague', 'None', 'Czech Republic', '14300', 5.9399999999999995),
#  (388, 5, '2019-07-16 00:00:00', 'Klanova 9/506', 'Prague', 'None', 'Czech Republic', '14700', 9.9),
#  (389, 16, '2019-07-18 00:00:00', '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', 16.83),
#  (390, 34, '2019-07-19 00:00:00', 'Rua da Assunção 53', 'Lisbon', 'None', 'Portugal', 'None', 2.9699999999999998),
#  (391, 30, '2019-07-20 00:00:00', '230 Elgin Street', 'Ottawa', 'ON', 'Canada', 'K2P 1L7', 3.96),
#  (392, 11, '2019-07-24 00:00:00', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', 7.92),
#  (393, 17, '2019-07-25 00:00:00', '1 Microsoft Way', 'Redmond', 'WA', 'USA', '98052-8300', 10.89),
#  (394, 31, '2019-07-27 00:00:00', '194A Chain Lake Drive', 'Halifax', 'NS', 'Canada', 'B3S 1C5', 7.92),
#  (395, 24, '2019-07-28 00:00:00', '162 E Superior Street', 'Chicago', 'IL', 'USA', '60611', 9.9),
#  (396, 42, '2019-07-29 00:00:00', '9, Place Louis Barthou', 'Bordeaux', 'None', 'France', '33000', 8.91),
#  (397, 36, '2019-07-31 00:00:00', 'Tauentzienstraße 8', 'Berlin', 'None', 'Germany', '10789', 6.93),
#  (398, 51, '2019-08-03 00:00:00', 'Celsiusg. 9', 'Stockholm', 'None', 'Sweden', '11230', 16.83),
#  (399, 51, '2019-08-03 00:00:00', 'Celsiusg. 9', 'Stockholm', 'None', 'Sweden', '11230', 11.879999999999999),
#  (400, 36, '2019-08-06 00:00:00', 'Tauentzienstraße 8', 'Berlin', 'None', 'Germany', '10789', 3.96),
#  (401, 46, '2019-08-06 00:00:00', '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', 'None', 9.9),
#  (402, 54, '2019-08-09 00:00:00', '110 Raeburn Pl', 'Edinburgh ', 'None', 'United Kingdom', 'EH4 1HH', 8.91),
#  (403, 54, '2019-08-10 00:00:00', '110 Raeburn Pl', 'Edinburgh ', 'None', 'United Kingdom', 'EH4 1HH', 8.91),
#  (404, 31, '2019-08-13 00:00:00', '194A Chain Lake Drive', 'Halifax', 'NS', 'Canada', 'B3S 1C5', 13.86),
#  (405, 6, '2019-08-14 00:00:00', 'Rilská 3174/6', 'Prague', 'None', 'Czech Republic', '14300', 7.92),
#  (406, 10, '2019-08-15 00:00:00', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', 1.98),
#  (407, 57, '2019-08-19 00:00:00', 'Calle Lira, 198', 'Santiago', 'None', 'Chile', 'None', 9.9),
#  (408, 34, '2019-08-20 00:00:00', 'Rua da Assunção 53', 'Lisbon', 'None', 'Portugal', 'None', 5.9399999999999995),
#  (409, 48, '2019-08-24 00:00:00', 'Lijnbaansgracht 120bg', 'Amsterdam', 'VV', 'Netherlands', '1016', 10.89),
#  (410, 7, '2019-08-27 00:00:00', 'Rotenturmstraße 4, 1010 Innere Stadt', 'Vienne', 'None', 'Austria', '1010', 3.96),
#  (411, 9, '2019-08-27 00:00:00', 'Sønder Boulevard 51', 'Copenhagen', 'None', 'Denmark', '1720', 1.98),
#  (412, 12, '2019-08-28 00:00:00', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', 7.92),
#  (413, 47, '2019-08-28 00:00:00', 'Via Degli Scipioni, 43', 'Rome', 'RM', 'Italy', '00192', 14.85),
#  (414, 54, '2019-08-30 00:00:00', '110 Raeburn Pl', 'Edinburgh ', 'None', 'United Kingdom', 'EH4 1HH', 9.9),
#  (415, 54, '2019-08-31 00:00:00', '110 Raeburn Pl', 'Edinburgh ', 'None', 'United Kingdom', 'EH4 1HH', 8.91),
#  (416, 5, '2019-08-31 00:00:00', 'Klanova 9/506', 'Prague', 'None', 'Czech Republic', '14700', 0.99),
#  (417, 24, '2019-09-01 00:00:00', '162 E Superior Street', 'Chicago', 'IL', 'USA', '60611', 9.9),
#  (418, 50, '2019-09-01 00:00:00', 'C/ San Bernardo 85', 'Madrid', 'None', 'Spain', '28015', 0.99),
#  (419, 3, '2019-09-02 00:00:00', '1498 rue Bélanger', 'Montréal', 'QC', 'Canada', 'H2G 1A7', 9.9),
#  (420, 20, '2019-09-05 00:00:00', '541 Del Medio Avenue', 'Mountain View', 'CA', 'USA', '94040-111', 9.9),
#  (421, 48, '2019-09-05 00:00:00', 'Lijnbaansgracht 120bg', 'Amsterdam', 'VV', 'Netherlands', '1016', 7.92),
#  (422, 53, '2019-09-07 00:00:00', '113 Lupus St', 'London', 'None', 'United Kingdom', 'SW1V 3EN', 6.93),
#  (423, 21, '2019-09-07 00:00:00', '801 W 4th Street', 'Reno', 'NV', 'USA', '89503', 10.89),
#  (424, 35, '2019-09-09 00:00:00', 'Rua dos Campeões Europeus de Viena, 4350', 'Porto', 'None', 'Portugal', 'None', 1.98),
#  (425, 14, '2019-09-13 00:00:00', '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', 0.99),
#  (426, 37, '2019-09-14 00:00:00', 'Berger Straße 10', 'Frankfurt', 'None', 'Germany', '60316', 4.95),
#  (427, 55, '2019-09-14 00:00:00', '421 Bourke Street', 'Sidney', 'NSW', 'Australia', '2010', 14.85),
#  (428, 43, '2019-09-17 00:00:00', '68, Rue Jouvence', 'Dijon', 'None', 'France', '21000', 3.96),
#  (429, 5, '2019-09-17 00:00:00', 'Klanova 9/506', 'Prague', 'None', 'Czech Republic', '14700', 10.89),
#  (430, 55, '2019-09-20 00:00:00', '421 Bourke Street', 'Sidney', 'NSW', 'Australia', '2010', 1.98),
#  (431, 8, '2019-09-21 00:00:00', 'Grétrystraat 63', 'Brussels', 'None', 'Belgium', '1000', 9.9),
#  (432, 32, '2019-09-23 00:00:00', '696 Osborne Street', 'Winnipeg', 'MB', 'Canada', 'R3L 2B9', 1.98),
#  (433, 33, '2019-09-24 00:00:00', '5112 48 Street', 'Yellowknife', 'NT', 'Canada', 'X1A 1N6', 2.9699999999999998),
#  (434, 26, '2019-09-27 00:00:00', '2211 W Berry Street', 'Fort Worth', 'TX', 'USA', '76110', 9.9),
#  (435, 38, '2019-09-28 00:00:00', 'Barbarossastraße 19', 'Berlin', 'None', 'Germany', '10779', 5.9399999999999995),
#  (436, 17, '2019-10-02 00:00:00', '1 Microsoft Way', 'Redmond', 'WA', 'USA', '98052-8300', 5.9399999999999995),
#  (437, 54, '2019-10-02 00:00:00', '110 Raeburn Pl', 'Edinburgh ', 'None', 'United Kingdom', 'EH4 1HH', 9.9),
#  (438, 23, '2019-10-04 00:00:00', '69 Salem Street', 'Boston', 'MA', 'USA', '2113', 10.89),
#  (439, 11, '2019-10-08 00:00:00', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', 6.93),
#  (440, 45, '2019-10-08 00:00:00', 'Erzsébet krt. 58.', 'Budapest', 'None', 'Hungary', 'H-1073', 2.9699999999999998),
#  (441, 44, '2019-10-26 00:00:00', 'Porthaninkatu 9', 'Helsinki', 'None', 'Finland', '00530', 6.93),
#  (442, 1, '2019-11-05 00:00:00', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', 3.96),
#  (443, 20, '2019-11-07 00:00:00', '541 Del Medio Avenue', 'Mountain View', 'CA', 'USA', '94040-111', 7.92),
#  (444, 52, '2019-11-08 00:00:00', '202 Hoxton Street', 'London', 'None', 'United Kingdom', 'N1 5LH', 8.91),
#  (445, 40, '2019-11-11 00:00:00', '8, Rue Hanovre', 'Paris', 'None', 'France', '75002', 3.96),
#  (446, 49, '2019-11-19 00:00:00', 'Ordynacka 10', 'Warsaw', 'None', 'Poland', '00-358', 8.91),
#  (447, 12, '2019-11-23 00:00:00', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', 10.89),
#  (448, 18, '2019-11-27 00:00:00', '627 Broadway', 'New York', 'NY', 'USA', '10012-2612', 9.9),
#  (449, 34, '2019-11-27 00:00:00', 'Rua da Assunção 53', 'Lisbon', 'None', 'Portugal', 'None', 16.83),
#  (450, 55, '2019-12-04 00:00:00', '421 Bourke Street', 'Sidney', 'NSW', 'Australia', '2010', 6.93),
#  (451, 46, '2019-12-13 00:00:00', '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', 'None', 0.99),
#  (452, 47, '2019-12-18 00:00:00', 'Via Degli Scipioni, 43', 'Rome', 'RM', 'Italy', '00192', 7.92),
#  (453, 31, '2019-12-19 00:00:00', '194A Chain Lake Drive', 'Halifax', 'NS', 'Canada', 'B3S 1C5', 4.95),
#  (454, 46, '2019-12-21 00:00:00', '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', 'None', 14.85),
#  (455, 28, '2019-12-24 00:00:00', '302 S 700 E', 'Salt Lake City', 'UT', 'USA', '84102', 4.95),
#  (456, 13, '2019-12-24 00:00:00', 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', 9.9),
#  (457, 37, '2019-12-25 00:00:00', 'Berger Straße 10', 'Frankfurt', 'None', 'Germany', '60316', 14.85),
#  (458, 42, '2019-12-26 00:00:00', '9, Place Louis Barthou', 'Bordeaux', 'None', 'France', '33000', 0.99),
#  (459, 50, '2019-12-26 00:00:00', 'C/ San Bernardo 85', 'Madrid', 'None', 'Spain', '28015', 1.98),
# ...
#  (462, 7, '2019-12-29 00:00:00', 'Rotenturmstraße 4, 1010 Innere Stadt', 'Vienne', 'None', 'Austria', '1010', 8.91),
#  (463, 34, '2019-12-30 00:00:00', 'Rua da Assunção 53', 'Lisbon', 'None', 'Portugal', 'None', 11.879999999999999),
#  (464, 1, '2019-12-31 00:00:00', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', 3.96),
#  (465, 21, '2020-01-12 00:00:00', '801 W 4th Street', 'Reno', 'NV', 'USA', '89503', 6.93),
#  (466, 30, '2020-01-19 00:00:00', '230 Elgin Street', 'Ottawa', 'ON', 'Canada', 'K2P 1L7', 3.96),
#  (467, 5, '2020-01-20 00:00:00', 'Klanova 9/506', 'Prague', 'None', 'Czech Republic', '14700', 9.9),
#  (468, 25, '2020-01-22 00:00:00', '319 N. Frances Street', 'Madison', 'WI', 'USA', '53703', 15.84),
#  (469, 14, '2020-01-28 00:00:00', '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', 0.99),
#  (470, 9, '2020-01-29 00:00:00', 'Sønder Boulevard 51', 'Copenhagen', 'None', 'Denmark', '1720', 1.98),
#  (471, 35, '2020-01-30 00:00:00', 'Rua dos Campeões Europeus de Viena, 4350', 'Porto', 'None', 'Portugal', 'None', 0.99),
#  (472, 7, '2020-01-31 00:00:00', 'Rotenturmstraße 4, 1010 Innere Stadt', 'Vienne', 'None', 'Austria', '1010', 2.9699999999999998),
#  (473, 58, '2020-02-02 00:00:00', '12,Community Centre', 'Delhi', 'None', 'India', '110017', 3.96),
#  (474, 4, '2020-02-04 00:00:00', 'Ullevålsveien 14', 'Oslo', 'None', 'Norway', '0171', 6.93),
#  (475, 11, '2020-02-06 00:00:00', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', 7.92),
#  (476, 6, '2020-02-11 00:00:00', 'Rilská 3174/6', 'Prague', 'None', 'Czech Republic', '14300', 10.89),
#  (477, 5, '2020-02-15 00:00:00', 'Klanova 9/506', 'Prague', 'None', 'Czech Republic', '14700', 6.93),
#  (478, 28, '2020-02-21 00:00:00', '302 S 700 E', 'Salt Lake City', 'UT', 'USA', '84102', 16.83),
#  (479, 46, '2020-02-21 00:00:00', '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', 'None', 16.83),
#  (480, 44, '2020-02-22 00:00:00', 'Porthaninkatu 9', 'Helsinki', 'None', 'Finland', '00530', 9.9),
#  (481, 43, '2020-02-25 00:00:00', '68, Rue Jouvence', 'Dijon', 'None', 'France', '21000', 3.96),
#  (482, 10, '2020-02-26 00:00:00', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', 7.92),
#  (483, 15, '2020-02-29 00:00:00', '700 W Pender Street', 'Vancouver', 'BC', 'Canada', 'V6C 1G8', 4.95),
#  (484, 47, '2020-03-02 00:00:00', 'Via Degli Scipioni, 43', 'Rome', 'RM', 'Italy', '00192', 2.9699999999999998),
#  (485, 37, '2020-03-05 00:00:00', 'Berger Straße 10', 'Frankfurt', 'None', 'Germany', '60316', 9.9),
#  (486, 18, '2020-03-05 00:00:00', '627 Broadway', 'New York', 'NY', 'USA', '10012-2612', 8.91),
#  (487, 27, '2020-03-11 00:00:00', '1033 N Park Ave', 'Tucson', 'AZ', 'USA', '85719', 9.9),
#  (488, 7, '2020-03-13 00:00:00', 'Rotenturmstraße 4, 1010 Innere Stadt', 'Vienne', 'None', 'Austria', '1010', 13.86),
#  (489, 43, '2020-03-14 00:00:00', '68, Rue Jouvence', 'Dijon', 'None', 'France', '21000', 2.9699999999999998),
#  (490, 19, '2020-03-14 00:00:00', '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', 8.91),
#  (491, 51, '2020-03-24 00:00:00', 'Celsiusg. 9', 'Stockholm', 'None', 'Sweden', '11230', 1.98),
#  (492, 54, '2020-03-25 00:00:00', '110 Raeburn Pl', 'Edinburgh ', 'None', 'United Kingdom', 'EH4 1HH', 4.95),
#  (493, 41, '2020-03-26 00:00:00', '11, Place Bellecour', 'Lyon', 'None', 'France', '69002', 3.96),
#  (494, 26, '2020-03-31 00:00:00', '2211 W Berry Street', 'Fort Worth', 'TX', 'USA', '76110', 9.9),
#  (495, 10, '2020-04-01 00:00:00', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', 0.99),
#  (496, 21, '2020-04-01 00:00:00', '801 W 4th Street', 'Reno', 'NV', 'USA', '89503', 7.92),
#  (497, 34, '2020-04-01 00:00:00', 'Rua da Assunção 53', 'Lisbon', 'None', 'Portugal', 'None', 6.93),
#  (498, 13, '2020-04-02 00:00:00', 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', 3.96),
#  (499, 17, '2020-04-03 00:00:00', '1 Microsoft Way', 'Redmond', 'WA', 'USA', '98052-8300', 9.9),
#  (500, 36, '2020-04-07 00:00:00', 'Tauentzienstraße 8', 'Berlin', 'None', 'Germany', '10789', 8.91),
#  (501, 11, '2020-04-09 00:00:00', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', 12.87),
#  (502, 53, '2020-04-10 00:00:00', '113 Lupus St', 'London', 'None', 'United Kingdom', 'SW1V 3EN', 3.96),
#  (503, 39, '2020-04-11 00:00:00', '4, Rue Milton', 'Paris', 'None', 'France', '75009', 9.9),
#  (504, 6, '2020-04-12 00:00:00', 'Rilská 3174/6', 'Prague', 'None', 'Czech Republic', '14300', 10.89),
#  (505, 19, '2020-04-14 00:00:00', '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', 0.99),
#  (506, 58, '2020-04-14 00:00:00', '12,Community Centre', 'Delhi', 'None', 'India', '110017', 15.84),
#  (507, 2, '2020-04-20 00:00:00', 'Theodor-Heuss-Straße 34', 'Stuttgart', 'None', 'Germany', '70174', 0.99),
#  (508, 38, '2020-04-22 00:00:00', 'Barbarossastraße 19', 'Berlin', 'None', 'Germany', '10779', 8.91),
#  (509, 48, '2020-04-27 00:00:00', 'Lijnbaansgracht 120bg', 'Amsterdam', 'VV', 'Netherlands', '1016', 6.93),
#  (510, 25, '2020-04-28 00:00:00', '319 N. Frances Street', 'Madison', 'WI', 'USA', '53703', 9.9),
#  (511, 24, '2020-05-01 00:00:00', '162 E Superior Street', 'Chicago', 'IL', 'USA', '60611', 6.93),
#  (512, 43, '2020-05-02 00:00:00', '68, Rue Jouvence', 'Dijon', 'None', 'France', '21000', 8.91),
#  (513, 41, '2020-05-03 00:00:00', '11, Place Bellecour', 'Lyon', 'None', 'France', '69002', 10.89),
#  (514, 25, '2020-05-14 00:00:00', '319 N. Frances Street', 'Madison', 'WI', 'USA', '53703', 2.9699999999999998),
#  (515, 23, '2020-05-15 00:00:00', '69 Salem Street', 'Boston', 'MA', 'USA', '2113', 2.9699999999999998),
#  (516, 23, '2020-05-16 00:00:00', '69 Salem Street', 'Boston', 'MA', 'USA', '2113', 1.98),
#  (517, 3, '2020-05-16 00:00:00', '1498 rue Bélanger', 'Montréal', 'QC', 'Canada', 'H2G 1A7', 8.91),
#  (518, 22, '2020-05-22 00:00:00', '120 S Orange Ave', 'Orlando', 'FL', 'USA', '32801', 1.98),
#  (519, 32, '2020-05-22 00:00:00', '696 Osborne Street', 'Winnipeg', 'MB', 'Canada', 'R3L 2B9', 6.93),
#  (520, 5, '2020-05-26 00:00:00', 'Klanova 9/506', 'Prague', 'None', 'Czech Republic', '14700', 9.9),
#  (521, 13, '2020-05-27 00:00:00', 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', 3.96),
#  (522, 22, '2020-05-27 00:00:00', '120 S Orange Ave', 'Orlando', 'FL', 'USA', '32801', 7.92),
#  (523, 50, '2020-05-29 00:00:00', 'C/ San Bernardo 85', 'Madrid', 'None', 'Spain', '28015', 7.92),
#  (524, 41, '2020-06-01 00:00:00', '11, Place Bellecour', 'Lyon', 'None', 'France', '69002', 4.95),
#  (525, 30, '2020-06-02 00:00:00', '230 Elgin Street', 'Ottawa', 'ON', 'Canada', 'K2P 1L7', 9.9),
#  (526, 5, '2020-06-08 00:00:00', 'Klanova 9/506', 'Prague', 'None', 'Czech Republic', '14700', 19.8),
#  (527, 57, '2020-06-09 00:00:00', 'Calle Lira, 198', 'Santiago', 'None', 'Chile', 'None', 10.89),
#  (528, 50, '2020-06-10 00:00:00', 'C/ San Bernardo 85', 'Madrid', 'None', 'Spain', '28015', 15.84),
#  (529, 24, '2020-06-12 00:00:00', '162 E Superior Street', 'Chicago', 'IL', 'USA', '60611', 13.86),
#  (530, 14, '2020-06-22 00:00:00', '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', 0.99),
#  (531, 44, '2020-06-22 00:00:00', 'Porthaninkatu 9', 'Helsinki', 'None', 'Finland', '00530', 11.879999999999999),
#  (532, 13, '2020-06-23 00:00:00', 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', 13.86),
#  (533, 11, '2020-06-24 00:00:00', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', 12.87),
#  (534, 10, '2020-06-25 00:00:00', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', 5.9399999999999995),
#  (535, 56, '2020-07-05 00:00:00', '307 Macacha Güemes', 'Buenos Aires', 'None', 'Argentina', '1106', 0.99),
#  (536, 1, '2020-07-06 00:00:00', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', 5.9399999999999995),
#  (537, 12, '2020-07-07 00:00:00', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', 7.92),
#  (538, 31, '2020-07-10 00:00:00', '194A Chain Lake Drive', 'Halifax', 'NS', 'Canada', 'B3S 1C5', 8.91),
#  (539, 46, '2020-07-12 00:00:00', '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', 'None', 0.99),
#  (540, 37, '2020-07-12 00:00:00', 'Berger Straße 10', 'Frankfurt', 'None', 'Germany', '60316', 10.89),
#  (541, 58, '2020-07-15 00:00:00', '12,Community Centre', 'Delhi', 'None', 'India', '110017', 2.9699999999999998),
#  (542, 34, '2020-07-18 00:00:00', 'Rua da Assunção 53', 'Lisbon', 'None', 'Portugal', 'None', 10.89),
#  (543, 17, '2020-07-23 00:00:00', '1 Microsoft Way', 'Redmond', 'WA', 'USA', '98052-8300', 2.9699999999999998),
#  (544, 1, '2020-07-24 00:00:00', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', 8.91),
#  (545, 33, '2020-07-26 00:00:00', '5112 48 Street', 'Yellowknife', 'NT', 'Canada', 'X1A 1N6', 7.92),
#  (546, 32, '2020-07-30 00:00:00', '696 Osborne Street', 'Winnipeg', 'MB', 'Canada', 'R3L 2B9', 6.93),
#  (547, 41, '2020-08-01 00:00:00', '11, Place Bellecour', 'Lyon', 'None', 'France', '69002', 9.9),
#  (548, 30, '2020-08-02 00:00:00', '230 Elgin Street', 'Ottawa', 'ON', 'Canada', 'K2P 1L7', 10.89),
#  (549, 2, '2020-08-10 00:00:00', 'Theodor-Heuss-Straße 34', 'Stuttgart', 'None', 'Germany', '70174', 10.89),
#  (550, 42, '2020-08-12 00:00:00', '9, Place Louis Barthou', 'Bordeaux', 'None', 'France', '33000', 9.9),
#  (551, 16, '2020-08-18 00:00:00', '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', 10.89),
#  (552, 30, '2020-08-19 00:00:00', '230 Elgin Street', 'Ottawa', 'ON', 'Canada', 'K2P 1L7', 5.9399999999999995),
#  (553, 7, '2020-08-26 00:00:00', 'Rotenturmstraße 4, 1010 Innere Stadt', 'Vienne', 'None', 'Austria', '1010', 4.95),
#  (554, 30, '2020-08-27 00:00:00', '230 Elgin Street', 'Ottawa', 'ON', 'Canada', 'K2P 1L7', 8.91),
#  (555, 55, '2020-09-04 00:00:00', '421 Bourke Street', 'Sidney', 'NSW', 'Australia', '2010', 1.98),
#  (556, 21, '2020-09-04 00:00:00', '801 W 4th Street', 'Reno', 'NV', 'USA', '89503', 10.89),
#  (557, 2, '2020-09-08 00:00:00', 'Theodor-Heuss-Straße 34', 'Stuttgart', 'None', 'Germany', '70174', 9.9),
#  (558, 17, '2020-09-11 00:00:00', '1 Microsoft Way', 'Redmond', 'WA', 'USA', '98052-8300', 10.89),
#  (559, 32, '2020-09-11 00:00:00', '696 Osborne Street', 'Winnipeg', 'MB', 'Canada', 'R3L 2B9', 5.9399999999999995),
#  (560, 5, '2020-09-11 00:00:00', 'Klanova 9/506', 'Prague', 'None', 'Czech Republic', '14700', 8.91),
#  (561, 23, '2020-09-12 00:00:00', '69 Salem Street', 'Boston', 'MA', 'USA', '2113', 6.93),
#  (562, 27, '2020-09-17 00:00:00', '1033 N Park Ave', 'Tucson', 'AZ', 'USA', '85719', 8.91),
#  (563, 5, '2020-09-19 00:00:00', 'Klanova 9/506', 'Prague', 'None', 'Czech Republic', '14700', 1.98),
#  (564, 15, '2020-09-20 00:00:00', '700 W Pender Street', 'Vancouver', 'BC', 'Canada', 'V6C 1G8', 5.9399999999999995),
#  (565, 53, '2020-09-23 00:00:00', '113 Lupus St', 'London', 'None', 'United Kingdom', 'SW1V 3EN', 9.9),
#  (566, 37, '2020-09-27 00:00:00', 'Berger Straße 10', 'Frankfurt', 'None', 'Germany', '60316', 4.95),
#  (567, 15, '2020-09-27 00:00:00', '700 W Pender Street', 'Vancouver', 'BC', 'Canada', 'V6C 1G8', 7.92),
#  (568, 35, '2020-10-01 00:00:00', 'Rua dos Campeões Europeus de Viena, 4350', 'Porto', 'None', 'Portugal', 'None', 6.93),
#  (569, 47, '2020-10-06 00:00:00', 'Via Degli Scipioni, 43', 'Rome', 'RM', 'Italy', '00192', 0.99),
#  (570, 52, '2020-10-07 00:00:00', '202 Hoxton Street', 'London', 'None', 'United Kingdom', 'N1 5LH', 2.9699999999999998),
#  (571, 51, '2020-10-09 00:00:00', 'Celsiusg. 9', 'Stockholm', 'None', 'Sweden', '11230', 2.9699999999999998),
#  (572, 34, '2020-10-13 00:00:00', 'Rua da Assunção 53', 'Lisbon', 'None', 'Portugal', 'None', 4.95),
#  (573, 27, '2020-10-16 00:00:00', '1033 N Park Ave', 'Tucson', 'AZ', 'USA', '85719', 10.89),
#  (574, 49, '2020-10-17 00:00:00', 'Ordynacka 10', 'Warsaw', 'None', 'Poland', '00-358', 10.89),
#  (575, 15, '2020-10-19 00:00:00', '700 W Pender Street', 'Vancouver', 'BC', 'Canada', 'V6C 1G8', 3.96),
#  (576, 45, '2020-10-19 00:00:00', 'Erzsébet krt. 58.', 'Budapest', 'None', 'Hungary', 'H-1073', 5.9399999999999995),
#  (577, 28, '2020-10-20 00:00:00', '302 S 700 E', 'Salt Lake City', 'UT', 'USA', '84102', 8.91),
#  (578, 25, '2020-10-21 00:00:00', '319 N. Frances Street', 'Madison', 'WI', 'USA', '53703', 11.879999999999999),
#  (579, 6, '2020-10-23 00:00:00', 'Rilská 3174/6', 'Prague', 'None', 'Czech Republic', '14300', 10.89),
#  (580, 24, '2020-10-25 00:00:00', '162 E Superior Street', 'Chicago', 'IL', 'USA', '60611', 9.9),
#  (581, 32, '2020-10-26 00:00:00', '696 Osborne Street', 'Winnipeg', 'MB', 'Canada', 'R3L 2B9', 13.86),
#  (582, 5, '2020-10-30 00:00:00', 'Klanova 9/506', 'Prague', 'None', 'Czech Republic', '14700', 17.82),
#  (583, 22, '2020-10-30 00:00:00', '120 S Orange Ave', 'Orlando', 'FL', 'USA', '32801', 10.89),
#  (584, 30, '2020-10-31 00:00:00', '230 Elgin Street', 'Ottawa', 'ON', 'Canada', 'K2P 1L7', 0.99),
#  (585, 40, '2020-10-31 00:00:00', '8, Rue Hanovre', 'Paris', 'None', 'France', '75002', 8.91),
#  (586, 55, '2020-11-01 00:00:00', '421 Bourke Street', 'Sidney', 'NSW', 'Australia', '2010', 10.89),
#  (587, 12, '2020-11-07 00:00:00', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', 1.98),
#  (588, 5, '2020-11-12 00:00:00', 'Klanova 9/506', 'Prague', 'None', 'Czech Republic', '14700', 0.99),
#  (589, 41, '2020-11-12 00:00:00', '11, Place Bellecour', 'Lyon', 'None', 'France', '69002', 10.89),
#  (590, 51, '2020-11-17 00:00:00', 'Celsiusg. 9', 'Stockholm', 'None', 'Sweden', '11230', 8.91),
#  (591, 16, '2020-11-20 00:00:00', '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', 6.93),
#  (592, 2, '2020-11-21 00:00:00', 'Theodor-Heuss-Straße 34', 'Stuttgart', 'None', 'Germany', '70174', 7.92),
#  (593, 12, '2020-11-23 00:00:00', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', 10.89),
#  (594, 31, '2020-11-24 00:00:00', '194A Chain Lake Drive', 'Halifax', 'NS', 'Canada', 'B3S 1C5', 2.9699999999999998),
#  (595, 23, '2020-11-27 00:00:00', '69 Salem Street', 'Boston', 'MA', 'USA', '2113', 7.92),
#  (596, 42, '2020-11-27 00:00:00', '9, Place Louis Barthou', 'Bordeaux', 'None', 'France', '33000', 5.9399999999999995),
#  (597, 13, '2020-11-28 00:00:00', 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', 6.93),
#  (598, 26, '2020-12-04 00:00:00', '2211 W Berry Street', 'Fort Worth', 'TX', 'USA', '76110', 4.95),
#  (599, 59, '2020-12-06 00:00:00', '3,Raj Bhavan Road', 'Bangalore', 'None', 'India', '560001', 7.92),
#  (600, 29, '2020-12-08 00:00:00', '796 Dundas Street West', 'Toronto', 'ON', 'Canada', 'M6J 1V1', 4.95),
#  (601, 44, '2020-12-08 00:00:00', 'Porthaninkatu 9', 'Helsinki', 'None', 'Finland', '00530', 10.89),
#  (602, 21, '2020-12-09 00:00:00', '801 W 4th Street', 'Reno', 'NV', 'USA', '89503', 6.93),
#  (603, 26, '2020-12-10 00:00:00', '2211 W Berry Street', 'Fort Worth', 'TX', 'USA', '76110', 4.95),
#  (604, 46, '2020-12-12 00:00:00', '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', 'None', 17.82),
#  (605, 35, '2020-12-17 00:00:00', 'Rua dos Campeões Europeus de Viena, 4350', 'Porto', 'None', 'Portugal', 'None', 3.96),
#  (606, 15, '2020-12-18 00:00:00', '700 W Pender Street', 'Vancouver', 'BC', 'Canada', 'V6C 1G8', 11.879999999999999),
#  (607, 59, '2020-12-19 00:00:00', '3,Raj Bhavan Road', 'Bangalore', 'None', 'India', '560001', 4.95),
#  (608, 49, '2020-12-20 00:00:00', 'Ordynacka 10', 'Warsaw', 'None', 'Poland', '00-358', 0.99),
#  (609, 14, '2020-12-20 00:00:00', '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', 2.9699999999999998),
#  (610, 55, '2020-12-21 00:00:00', '421 Bourke Street', 'Sidney', 'NSW', 'Australia', '2010', 6.93),
#  (611, 52, '2020-12-27 00:00:00', '202 Hoxton Street', 'London', 'None', 'United Kingdom', 'N1 5LH', 1.98),
#  (612, 33, '2020-12-27 00:00:00', '5112 48 Street', 'Yellowknife', 'NT', 'Canada', 'X1A 1N6', 11.879999999999999),
#  (613, 20, '2020-12-29 00:00:00', '541 Del Medio Avenue', 'Mountain View', 'CA', 'USA', '94040-111', 8.91),
#  (614, 53, '2020-12-30 00:00:00', '113 Lupus St', 'London', 'None', 'United Kingdom', 'SW1V 3EN', 12.87)]
